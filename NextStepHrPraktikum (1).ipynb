# %% [markdown]
# ### NestStepHR Links
# - Google Meeting Link: https://meet.google.com/udg-vypy-ojd
# - Notion: https://nxhr.notion.site/Constantins-Praktikum-10d35192da108009b393f23a25684158

# %% [markdown]
# GitHub: https://github.com/

# %% [markdown]
# ### Datenbank
# postgresql

# %% [markdown]
# Ideen und Impulse:
# - virtual machine steuerung

# %% [markdown]
# - über text datei einlesen
#     - mehr seiten pasen (... 2, 3, 4, ...) 30stellen bekommen
# - gleiche datenbankeinträge löschen
# - db datenbank erstellen
# - import matplotlib, und daten plotten
# - selenium zum automatisieren

# %% [markdown]
# - Links Sammlen für Stellen für mathematiker:
# - welche bildungformen für mathiker
# - studiengänge:
# - übersichtseiten für arbeitsplätze als mathematiker (20stk): indeed, duckduckgo, google

# %% [markdown]
# https://www.digitalocean.com/community/tutorials/how-to-work-with-web-data-using-requests-and-beautiful-soup-with-python-3

# %% [markdown]
# # Sammeln von Webseiten

# %% [markdown]
# ##### Bildungsformen
# - Bechelor
# - Master
# - Duales Studium
# - Lehramt Mathelerer
# - Promotion (Doktor der Mathematik)
# - Weiterbildung und Zertifikatskurse
# - Fernstudium Mathematik
# - Doktor

# %%
# Studiengänge 
liste_studiengang = {
    "Finanz- und Wirtschaftsmathematik" : "https://jobs.volkswagen-group.com/VWFS/job/Braunschweig-Vollzeitstudium-Finanz-und-Wirtschaftsmathematik-%28B_-Sc_%29-2025-%28mwd%29-38112/1077044601/?traci_c=Vollzeitstudium|Wirtschaftsinformatik:DM-P:&traci_s=EB:VWFS:SEA:Google:SearchAd:2023-09:&traci_ee=18407959109:157135801149:687038422746::::&traci_t=mathematische%20studieng%C3%A4nge:e&s_kwcid=AL!10901!3!687038422746!e!!g!!mathematische%20studieng%C3%A4nge&gad_source=1&gclid=Cj0KCQjw3vO3BhCqARIsAEWblcBaURAfF0TraE7hgmxmUs1e7af8siaQ2ZTRVUs2Qs6hovDCOxXunmYaAmLBEALw_wcB",
    "Katholische Hochschule": "https://www.ku.de/studienangebot/mathe-data-digital?mtm_campaign=Digitalhub&mtm_source=googleads&gad_source=1&gclid=Cj0KCQjw3vO3BhCqARIsAEWblcDA0_bbHGA5k2eNg4o--3lUd4uII5JVHz_V_Fot7uz7HGmjOydDgmQaAlLiEALw_wcB",
    "Superprof": "https://www.superprof.de/blog/mathematische-studiengaenge/",
    "Hochschul Kompass" : "https://www.hochschulkompass.de/studium/studiengangsuche/erweiterte-studiengangsuche.html?tx_szhrksearch_pi1%5Bsearch%5D=1&tx_szhrksearch_pi1%5Bstudtyp%5D=3&tx_szhrksearch_pi1%5BQUICK%5D=1&tx_szhrksearch_pi1%5Bfach%5D=mathematik+",
    "studierende.de": "https://studieren.de/mathematik.hochschulliste.t-0.c-149.html"
    
}
a =[
    "https://jobs.volkswagen-group.com/VWFS/job/Braunschweig-Vollzeitstudium-Finanz-und-Wirtschaftsmathematik-%28B_-Sc_%29-2025-%28mwd%29-38112/1077044601/?traci_c=Vollzeitstudium|Wirtschaftsinformatik:DM-P:&traci_s=EB:VWFS:SEA:Google:SearchAd:2023-09:&traci_ee=18407959109:157135801149:687038422746::::&traci_t=mathematische%20studieng%C3%A4nge:e&s_kwcid=AL!10901!3!687038422746!e!!g!!mathematische%20studieng%C3%A4nge&gad_source=1&gclid=Cj0KCQjw3vO3BhCqARIsAEWblcBaURAfF0TraE7hgmxmUs1e7af8siaQ2ZTRVUs2Qs6hovDCOxXunmYaAmLBEALw_wcB",
    "https://www.ku.de/studienangebot/mathe-data-digital?mtm_campaign=Digitalhub&mtm_source=googleads&gad_source=1&gclid=Cj0KCQjw3vO3BhCqARIsAEWblcDA0_bbHGA5k2eNg4o--3lUd4uII5JVHz_V_Fot7uz7HGmjOydDgmQaAlLiEALw_wcB",
    "https://www.superprof.de/blog/mathematische-studiengaenge/",
    "https://www.hochschulkompass.de/studium/studiengangsuche/erweiterte-studiengangsuche.html?tx_szhrksearch_pi1%5Bsearch%5D=1&tx_szhrksearch_pi1%5Bstudtyp%5D=3&tx_szhrksearch_pi1%5BQUICK%5D=1&tx_szhrksearch_pi1%5Bfach%5D=mathematik+",
    "https://studieren.de/mathematik.hochschulliste.t-0.c-149.html"
]
#Technomathematik
#Computational Science
#Statistik und Data Science

# %%
#requests.get(a[-1]).text

# %%
# Arbeitstellen 
liste_arbeitstellen= [
    'https://www.stepstone.de/jobs/mathematiker-in?searchOrigin=Homepage_top-search&q=Mathematiker%2Fin',
    'https://de.indeed.com/jobs?q=Mathematiker&l=&from=searchOnHP&vjk=4502c46a336fc4de',
    'https://de.indeed.com/jobs?q=Mathematiker&start=10&vjk=9e9d7028d095b769'
    'https://de.linkedin.com/jobs/search?keywords=Mathematiker&location=Deutschland&geoId=101282230&trk=guest_homepage-basic_jobs-search-bar_search-submit&position=1&pageNum=0',
    'https://www.xing.com/jobs/search?sc_o=losp_jobs_search_button_click&sc_o_PropActionOrigin=losp_job_search&keywords=Mathematiker&id=9e84e94a22c26b4f4a24879c7f3caaf5',
    'https://www.jobware.de/',
    'https://www.academics.de',
    'https://www.monster.de',
    'https://www.mathematik.de/stellen',
    'https://www.glassdoor.de',
    'https://stellenmarkt.faz.net/',
    'https://www.efinancialcareers.de', 
    'https://www.uni-stellenmarkt.de', 
    'https://www.researchgate.net/jobs',
    'https://www.jobvector.de',
    'https://www.mathjobs.org',
    'https://www.google.com/search?sca_esv=433eaf814a238d09&sxsrf=ADLYWILCtL-NPySfvBn--Li84PHI-bQOyA:1727939857501&q=google+mathematiker+jobs&udm=8&fbs=AEQNm0A6bwEop21ehxKWq5cj-cHaEkZU5BN01nVAK6tnGIJfST4N_HIHYjN6Cbf60WPIIu3_2EaIVy-VW1POt3ZO-ioZiHlRcMLaWm3Pqbb92c-1wmalzDz9boxZ1cxxrhgDKM1BhjeLEJh0f7Df_9XJIAv339-XOegEGmTJsNdK7s9--BxE4g_TFjuiPyEdcMZLAJdSJBIo&sa=X&ved=2ahUKEwij9pjL1fGIAxX_1wIHHdoyC2sQs6gLegQIFhAB&biw=1422&bih=659&dpr=1.35&jbr=sep:0'
    
    ]

# %%
import requests
from bs4 import BeautifulSoup # screen-scraping 
import json
url = "https://www.xing.com/jobs/search?sc_o=losp_jobs_search_button_click&sc_o_PropActionOrigin=losp_job_search&keywords=Mathematiker&id=9e84e94a22c26b4f4a24879c7f3caaf5"

# %% [markdown]
# # Auslesen von HTML

# %%
# Beispielcode für das Testen einer Request (ging ja nicht immer bei allen Seiten)

import requests # Anfrage an die Webseite

def get_response(url):
    timeout_seconds = 5  # Timeout auf 5 Sekunden setzen

    try:
        response = requests.get(url, timeout=timeout_seconds)

        # Status Code check
        if response.status_code == 200:
            # Überprüfen, ob Inhalt vorhanden ist
            if response.content:
                print("Inhalt erfolgreich geladen.")
                print(response.text[:500])  # Optional: Erste 500 Zeichen des Inhalts ausgeben
                return True
            else:
                print("Kein Inhalt vorhanden.")
        else:
            print(f"Fehler: Status Code ist {response.status_code}")

    except requests.Timeout:
        print(f"Timeout nach {timeout_seconds} Sekunden.")
    except requests.ConnectionError:
        print("Verbindungsfehler. Keine Verbindung zum Server.")
    except requests.RequestException as e:
        # Fängt alle anderen Request-Fehler ab
        print(f"Ein Fehler ist aufgetreten: {e}")

positiv_resp = []

for liste in liste_arbeitstellen:
    resp = get_response(liste)
    if resp == True:  # 200 steht für "OK" in HTTP
        positiv_resp.append(liste)
    else: 
        print(liste, 'negative')
        
print(positiv_resp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 33
#      29         print(f"Ein Fehler ist aufgetreten: {e}")
#      31 positiv_resp = []
# ---> 33 for liste in liste_arbeitstellen:
#      34     resp = get_response(liste)
#      35     if resp == True:  # 200 steht für "OK" in HTTP
#
# NameError: name 'liste_arbeitstellen' is not defined

# %%
for wert in positiv_resp:
    print(wert)

html = requests.get(positiv_resp[0]).text
print(html)
soup = BeautifulSoup(html, 'html.parser')
#print(soup.prettify())
# Out:
# https://www.xing.com/jobs/search?sc_o=losp_jobs_search_button_click&sc_o_PropActionOrigin=losp_job_search&keywords=Mathematiker&id=9e84e94a22c26b4f4a24879c7f3caaf5
# https://www.jobware.de/
# https://www.academics.de
# https://www.monster.de
# https://www.mathematik.de/stellen
# https://stellenmarkt.faz.net/
# https://www.uni-stellenmarkt.de
# https://www.jobvector.de
# https://www.mathjobs.org
# https://www.google.com/search?sca_esv=433eaf814a238d09&sxsrf=ADLYWILCtL-NPySfvBn--Li84PHI-bQOyA:1727939857501&q=google+mathematiker+jobs&udm=8&fbs=AEQNm0A6bwEop21ehxKWq5cj-cHaEkZU5BN01nVAK6tnGIJfST4N_HIHYjN6Cbf60WPIIu3_2EaIVy-VW1POt3ZO-ioZiHlRcMLaWm3Pqbb92c-1wmalzDz9boxZ1cxxrhgDKM1BhjeLEJh0f7Df_9XJIAv339-XOegEGmTJsNdK7s9--BxE4g_TFjuiPyEdcMZLAJdSJBIo&sa=X&ved=2ahUKEwij9pjL1fGIAxX_1wIHHdoyC2sQs6gLegQIFhAB&biw=1422&bih=659&dpr=1.35&jbr=sep:0
# <!DOCTYPE html>
# <html class="system" lang="de">
# <head>
# <meta charset="utf-8"/>
# <meta data-rh="true" charset="utf-8"/><meta data-rh="true" name="viewport" content="width=device-width, minimum-scale=1, maximum-scale=1"/><meta data-rh="true" name="robots" content="noindex, follow"/><meta data-rh="true" name="theme-color" content="#C6F16D"/>
# <title data-rh="true">XING</title>
# <script src="https://static.xingcdn.com/crate/runtime/main-3ec17ff007abc046.js" defer></script>
# <link data-rh="true" rel="icon" href="/favicon.ico"/><link data-rh="true" href="https://static.xingcdn.com/crate/root-b33b72b3/XING-Sans-Regular-bdc063ec50e5759ac9d4d895679c1380.woff2" rel="preload" as="font" crossorigin="anonymous" type="font/woff2"/><link data-rh="true" href="https://static.xingcdn.com/crate/root-b33b72b3/XING-Sans-Bold-a8a92bd52acc953c9ac5d643b2ea0bd3.woff2" rel="preload" as="font" crossorigin="anonymous" type="font/woff2"/>
# <style data-rh="true" >@font-face {font-family: 'XING Sans';font-display: block;font-style: normal;font-weight: 400;src: url(https://static.xingcdn.com/crate/root-b33b72b3/XING-Sans-Regular-bdc063ec50e5759ac9d4d895679c1380.woff2) format("woff2"),url(https://static.xingcdn.com/crate/root-b33b72b3/XING-Sans-Regular-23b3ddc3411d2aad68de58be373e8458.woff) format("woff");}@font-face {font-family: 'XING Sans';font-display: block;font-style: bold;font-weight: 700;src: url(https://static.xingcdn.com/crate/root-b33b72b3/XING-Sans-Bold-a8a92bd52acc953c9ac5d643b2ea0bd3.woff2) format("woff2"),url(https://static.xingcdn.com/crate/root-b33b72b3/XING-Sans-Bold-3ba114329689bcfb7ffae73fb316f924.woff) format("woff");}</style><style data-rh="true" >body {font-family: 'XING Sans', 'Trebuchet MS', Arial, 'Helvetica Neue', sans-serif;}</style>
# <script defer>function i(){window.location.href="https://faq.xing.com/de/browser"}function n(n){try{var t=n();if(t instanceof Promise){t.then(function(n){if(!n)i()},function(){return i()})}else if(!t){i()}}catch(f){i()}}n(function(){return typeof Array.prototype.flatMap==="function"});n(function(){return typeof Intl.Locale==="function"});</script>
# <link rel="stylesheet" type="text/css" href="https://static.xingcdn.com/crate/root-b33b72b3/235674d2968f9442.css">
# <link rel="stylesheet" type="text/css" href="https://static.xingcdn.com/crate/search-4539e462/17ad09a1a02f8291.css">
# <style data-styled="true" data-styled-version="5.3.11">.jHJcmV{padding-block:24px;padding-inline:16px;min-width:320px;}/*!sc*/
# @media (min-width:740px){.jHJcmV{padding-inline:32px;}}/*!sc*/
# @media (min-width:1268px){.jHJcmV{padding-inline:68px;}}/*!sc*/
# data-styled.g1[id="section__Section-sc-b7df443b-0"]{content:"jHJcmV,"}/*!sc*/
# .eEeoZI{background-image:url(https://static.xingcdn.com/crate/search-4539e462/Background_01_7x2_a-1a945cb4c68955bc077337e259bc436f.svg);background-repeat:no-repeat;background-size:cover;background-position-x:15%;}/*!sc*/
# @media (max-width:539px){.eEeoZI{background-image:url(https://static.xingcdn.com/crate/search-4539e462/Background_01_1x1_a-20ae4d5fa6c5e440da465437787dcf56.svg);background-position-y:77%;}}/*!sc*/
# @media (min-width:1024px){.eEeoZI{background-size:110%;background-position-x:55%;}}/*!sc*/
# data-styled.g2[id="section__BackgroundSection-sc-b7df443b-1"]{content:"eEeoZI,"}/*!sc*/
# .jaaYMO{width:100%;margin:0 auto;box-sizing:border-box;max-width:944px;}/*!sc*/
# @media (min-width:740px){.jaaYMO{padding-inline:0;}}/*!sc*/
# .dpOZjv{width:100%;margin:0 auto;box-sizing:border-box;max-width:1256px;}/*!sc*/
# @media (min-width:740px){.dpOZjv{padding-inline:0;}}/*!sc*/
# data-styled.g3[id="container__Container-sc-e4e4aa06-0"]{content:"jaaYMO,dpOZjv,"}/*!sc*/
# .emiGcc{display:none;}/*!sc*/
# @media (min-width:1024px){.emiGcc{display:block;}}/*!sc*/
# data-styled.g6[id="conditionals__OnlyOnLarge-sc-54c4fd56-2"]{content:"emiGcc,"}/*!sc*/
# .eUoSdI{line-height:1.5;margin-left:0;margin-right:0;margin-top:0;padding:0;font-weight:700;font-size:16px;margin-bottom:12px;}/*!sc*/
# .bIdOSM{line-height:1.5;margin-left:0;margin-right:0;margin-top:0;padding:0;font-weight:400;font-size:14px;margin-bottom:12px;}/*!sc*/
# .bIdOSM.bIdOSM{margin:0;}/*!sc*/
# .kXwjjV{line-height:1.5;margin-left:0;margin-right:0;margin-top:0;padding:0;line-height:1.25;font-weight:400;font-size:14px;margin-bottom:12px;}/*!sc*/
# .kXwjjV.kXwjjV{margin:0;}/*!sc*/
# .kXsghf{line-height:1.5;margin-left:0;margin-right:0;margin-top:0;padding:0;line-height:1.25;font-weight:400;font-size:16px;margin-bottom:12px;}/*!sc*/
# .kXsghf.kXsghf{margin:0;}/*!sc*/
# .hjZJNb{line-height:1.5;margin-left:0;margin-right:0;margin-top:0;padding:0;font-weight:400;font-size:16px;margin-bottom:12px;}/*!sc*/
# data-styled.g18[id="body-copy-styles__BodyCopy-sc-846cf07c-0"]{content:"eUoSdI,bIdOSM,kXwjjV,kXsghf,hjZJNb,"}/*!sc*/
# .jseXwX{font-weight:700;line-height:1.25;margin-left:0;margin-right:0;margin-top:0;padding:0;font-size:18px;margin-bottom:16px;}/*!sc*/
# .cIMjeA{font-weight:700;line-height:1.25;margin-left:0;margin-right:0;margin-top:0;padding:0;font-size:16px;margin-bottom:12px;}/*!sc*/
# .cIMjeA.cIMjeA{margin:0;}/*!sc*/
# .jfqtGd{font-weight:700;line-height:1.25;margin-left:0;margin-right:0;margin-top:0;padding:0;font-size:16px;margin-bottom:12px;}/*!sc*/
# .ktxXZv{font-weight:700;line-height:1.25;margin-left:0;margin-right:0;margin-top:0;padding:0;font-size:16px;margin-bottom:12px;}/*!sc*/
# @media (min-width:883px) and (max-width:1023px),(min-width:1113px){.ktxXZv{font-size:18px;margin-bottom:16px;}}/*!sc*/
# .ktxXZv.ktxXZv{margin:0;}/*!sc*/
# data-styled.g20[id="headline-styles__Headline-sc-df17ff0a-0"]{content:"jseXwX,cIMjeA,jfqtGd,ktxXZv,"}/*!sc*/
# .kVZtFR{font-weight:700;margin-left:0;margin-right:0;margin-top:0;padding:0;font-size:32px;line-height:1.2;margin-bottom:16px;}/*!sc*/
# data-styled.g21[id="hero-styles__Hero-sc-5259601e-0"]{content:"kVZtFR,"}/*!sc*/
# .dnVgee{color:var(--xdlColorTextSecondary);}/*!sc*/
# data-styled.g22[id="meta-styles__Meta-sc-656dc5f-0"]{content:"dnVgee,"}/*!sc*/
# .kSaBeO{-webkit-animation-direction:alternate;animation-direction:alternate;-webkit-animation-duration:1000ms;animation-duration:1000ms;-webkit-animation-iteration-count:infinite;animation-iteration-count:infinite;-webkit-animation-name:cfkuO;animation-name:cfkuO;-webkit-animation-timing-function:cubic-bezier(0.4,0,0.2,1);animation-timing-function:cubic-bezier(0.4,0,0.2,1);background-color:var(--xdlColorSkeletonPrimary);}/*!sc*/
# data-styled.g25[id="skeleton-base-styles__SkeletonBase-sc-60102090-0"]{content:"kSaBeO,"}/*!sc*/
# .eBrPkz{max-height:100px;border-radius:100px;height:20px;width:33%;}/*!sc*/
# .ddFXqe{max-height:100px;border-radius:100px;height:20px;width:50%;}/*!sc*/
# .citkue{max-height:100px;border-radius:100px;width:100%;}/*!sc*/
# data-styled.g27[id="skeleton-pill-shape-styles__SkeletonPillShape-sc-45e3555-0"]{content:"eBrPkz,ddFXqe,citkue,"}/*!sc*/
# .hClERs{overflow:hidden;width:100%;width:100%;}/*!sc*/
# .dmWGQY{overflow:hidden;width:100%;border-radius:32px;width:68px;height:32px;}/*!sc*/
# .gGBfAh{overflow:hidden;width:100%;border-radius:2px;width:100%;height:24px;width:24px;}/*!sc*/
# .fKLrbv{overflow:hidden;width:100%;border-radius:2px;width:100%;height:12px;}/*!sc*/
# data-styled.g28[id="skeleton-rectangle-styles__SkeletonRectangle-sc-b052e428-0"]{content:"hClERs,dmWGQY,gGBfAh,fKLrbv,"}/*!sc*/
# .qlDYu{-webkit-animation-direction:alternate;animation-direction:alternate;-webkit-animation-duration:1000ms;animation-duration:1000ms;-webkit-animation-iteration-count:infinite;animation-iteration-count:infinite;-webkit-animation-name:xdnOO;animation-name:xdnOO;-webkit-animation-timing-function:cubic-bezier(0.4,0,0.2,1);animation-timing-function:cubic-bezier(0.4,0,0.2,1);fill:var(--xdlColorSkeletonPrimary);}/*!sc*/
# data-styled.g29[id="skeleton-super-ellipse-styles__SkeletonSuperEllipse-sc-c4622d7a-0"]{content:"qlDYu,"}/*!sc*/
# .gbRwUO{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# data-styled.g30[id="skeleton-body-copy-styles__BodyCopy-sc-52518a8d-0"]{content:"gbRwUO,"}/*!sc*/
# .BtOOn{margin-block-end:8px;}/*!sc*/
# .BtOOn:last-child{width:66%;}/*!sc*/
# .BtOOn:last-child{margin-block-end:0;}/*!sc*/
# .htohgq{margin-block-end:8px;}/*!sc*/
# .htohgq:last-child{margin-block-end:0;}/*!sc*/
# data-styled.g31[id="skeleton-body-copy-styles__BodyCopyRow-sc-52518a8d-1"]{content:"BtOOn,htohgq,"}/*!sc*/
# .gzuzha{height:32px;}/*!sc*/
# data-styled.g32[id="skeleton-button-styles__Button-sc-c7ab5467-0"]{content:"gzuzha,"}/*!sc*/
# .hFPFKz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# data-styled.g33[id="skeleton-headline-styles__Headline-sc-5d244760-0"]{content:"hFPFKz,"}/*!sc*/
# .eUmVwU{height:28px;margin-block-end:12px;}/*!sc*/
# .eUmVwU:last-child{margin-block-end:0;}/*!sc*/
# .eREOqC{height:20px;margin-block-end:10px;}/*!sc*/
# .eREOqC:last-child{margin-block-end:0;}/*!sc*/
# .hFsyvC{height:20px;margin-block-end:10px;}/*!sc*/
# @media (min-width:740px){.hFsyvC{height:28px;margin-block-end:12px;}}/*!sc*/
# .hFsyvC:last-child{margin-block-end:0;}/*!sc*/
# .cIBPZx{height:28px;margin-block-end:12px;}/*!sc*/
# .cIBPZx:last-child{width:66%;}/*!sc*/
# .cIBPZx:last-child{margin-block-end:0;}/*!sc*/
# data-styled.g34[id="skeleton-headline-styles__HeadlineRow-sc-5d244760-1"]{content:"eUmVwU,eREOqC,hFsyvC,cIBPZx,"}/*!sc*/
# .jRRowA{height:calc(48px + (2 * 1px));width:calc(48px + (2 * 1px));}/*!sc*/
# @media (min-width:740px){.jRRowA{height:calc(92px + (2 * 2px));width:calc(92px + (2 * 2px));}}/*!sc*/
# data-styled.g46[id="skeleton-profile-image-styles__SuperEllipse-sc-ce4d7962-0"]{content:"jRRowA,"}/*!sc*/
# .gWUBoJ{height:24px;width:24px;margin-inline-end:8px;}/*!sc*/
# data-styled.g59[id="button-styles__IconContainer-sc-9c115803-0"]{content:"gWUBoJ,"}/*!sc*/
# .clEXVA{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;border-radius:50px;border:none;color:var(--xdlColorText);display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-size:14px;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding:0;position:relative;-webkit-text-decoration:none;text-decoration:none;vertical-align:top;z-index:0;color:var(--xdlColorText);font-size:16px;height:42px;min-width:42px;padding-inline-end:calc(42px / 2);padding-inline-start:calc(42px / 2);padding:0;}/*!sc*/
# .clEXVA::after{border-radius:50px;box-sizing:border-box;content:'';cursor:pointer;height:100%;-webkit-inset-block-start:0;-ms-intb-rlock-start:0;inset-block-start:0;inset-inline-start:0;position:absolute;-webkit-transition-duration:150ms;transition-duration:150ms;-webkit-transition-property:-webkit-transform,background-color;-webkit-transition-property:transform,background-color;transition-property:transform,background-color;-webkit-transition-timing-function:cubic-bezier(0,0,0.2,1);transition-timing-function:cubic-bezier(0,0,0.2,1);width:100%;z-index:-100;}/*!sc*/
# .clEXVA:hover,.clEXVA:focus{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .clEXVA:disabled{cursor:default;}/*!sc*/
# .clEXVA:disabled::after{cursor:default;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .clEXVA::after{background-color:var(--xdlColorControlFillTertiary);}/*!sc*/
# .clEXVA:hover::after{background-color:var(--xdlColorHoverTertiary);}/*!sc*/
# @media (hover:none){.clEXVA:hover::after{background-color:var(--xdlColorControlFillTertiary);}}/*!sc*/
# .clEXVA:active{color:var(--xdlColorTextInvert);}/*!sc*/
# .clEXVA:active::after{background-color:var(--xdlColorSelected);-webkit-transform:scale(0.95);-ms-transform:scale(0.95);transform:scale(0.95);}/*!sc*/
# .clEXVA:disabled{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .clEXVA:disabled::after{background-color:var(--xdlColorDisabledSoft);-webkit-transform:none;-ms-transform:none;transform:none;}/*!sc*/
# .clEXVA:disabled::after:hover::after{background-color:transparent;}/*!sc*/
# .clEXVA[aria-label='loading']::after{background-color:var(--xdlColorControlFillTertiary);}/*!sc*/
# .clEXVA .button-styles__IconContainer-sc-9c115803-0{margin:0;}/*!sc*/
# .iCWLyT{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;border-radius:50px;border:none;color:var(--xdlColorText);display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-size:14px;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding:0;position:relative;-webkit-text-decoration:none;text-decoration:none;vertical-align:top;z-index:0;color:var(--xdlColorText);font-size:16px;height:42px;min-width:42px;padding-inline-end:calc(42px / 2);padding-inline-start:calc(42px / 2);}/*!sc*/
# .iCWLyT::after{border-radius:50px;box-sizing:border-box;content:'';cursor:pointer;height:100%;-webkit-inset-block-start:0;-ms-intb-rlock-start:0;inset-block-start:0;inset-inline-start:0;position:absolute;-webkit-transition-duration:150ms;transition-duration:150ms;-webkit-transition-property:-webkit-transform,background-color;-webkit-transition-property:transform,background-color;transition-property:transform,background-color;-webkit-transition-timing-function:cubic-bezier(0,0,0.2,1);transition-timing-function:cubic-bezier(0,0,0.2,1);width:100%;z-index:-100;}/*!sc*/
# .iCWLyT:hover,.iCWLyT:focus{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .iCWLyT:disabled{cursor:default;}/*!sc*/
# .iCWLyT:disabled::after{cursor:default;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .iCWLyT::after{background-color:var(--xdlColorControlFillTertiary);}/*!sc*/
# .iCWLyT:hover::after{background-color:var(--xdlColorHoverTertiary);}/*!sc*/
# @media (hover:none){.iCWLyT:hover::after{background-color:var(--xdlColorControlFillTertiary);}}/*!sc*/
# .iCWLyT:active{color:var(--xdlColorTextInvert);}/*!sc*/
# .iCWLyT:active::after{background-color:var(--xdlColorSelected);-webkit-transform:scale(0.95);-ms-transform:scale(0.95);transform:scale(0.95);}/*!sc*/
# .iCWLyT:disabled{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .iCWLyT:disabled::after{background-color:var(--xdlColorDisabledSoft);-webkit-transform:none;-ms-transform:none;transform:none;}/*!sc*/
# .iCWLyT:disabled::after:hover::after{background-color:transparent;}/*!sc*/
# .iCWLyT[aria-label='loading']::after{background-color:var(--xdlColorControlFillTertiary);}/*!sc*/
# .bIQunG{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;border-radius:50px;border:none;color:var(--xdlColorText);display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-size:14px;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding:0;position:relative;-webkit-text-decoration:none;text-decoration:none;vertical-align:top;z-index:0;color:var(--xdlColorText);font-size:16px;height:42px;min-width:42px;padding-inline-end:calc(42px / 2);padding-inline-start:calc(42px / 2);}/*!sc*/
# .bIQunG::after{border-radius:50px;box-sizing:border-box;content:'';cursor:pointer;height:100%;-webkit-inset-block-start:0;-ms-intb-rlock-start:0;inset-block-start:0;inset-inline-start:0;position:absolute;-webkit-transition-duration:150ms;transition-duration:150ms;-webkit-transition-property:-webkit-transform,background-color;-webkit-transition-property:transform,background-color;transition-property:transform,background-color;-webkit-transition-timing-function:cubic-bezier(0,0,0.2,1);transition-timing-function:cubic-bezier(0,0,0.2,1);width:100%;z-index:-100;}/*!sc*/
# .bIQunG:hover,.bIQunG:focus{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .bIQunG:disabled{cursor:default;}/*!sc*/
# .bIQunG:disabled::after{cursor:default;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .bIQunG::after{background-color:transparent;border-color:var(--xdlColorControlBorderSecondary);border-style:solid;border-width:2px;}/*!sc*/
# .bIQunG:hover{color:var(--xdlColorText);}/*!sc*/
# @media (hover:none){.bIQunG:hover{color:var(--xdlColorText);}}/*!sc*/
# .bIQunG:hover::after{background:var(--xdlColorButtonSecondaryHover);}/*!sc*/
# @media (hover:none){.bIQunG:hover::after{background-color:var(--xdlColorButtonSecondaryHover);color:var(--xdlColorText);}}/*!sc*/
# .bIQunG:active{color:var(--xdlColorTextInvert);}/*!sc*/
# .bIQunG:active::after{background-color:var(--xdlColorSelected);border-color:var(--xdlColorSelected);-webkit-transform:scale(0.95);-ms-transform:scale(0.95);transform:scale(0.95);}/*!sc*/
# .bIQunG:disabled{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .bIQunG:disabled::after{background-color:transparent;border-color:var(--xdlColorDisabledStrong);color:var(--xdlColorDisabledStrong);-webkit-transform:none;-ms-transform:none;transform:none;}/*!sc*/
# .bIQunG[aria-label='loading']::after{background-color:transparent;border-color:var(--xdlColorControlBorderSecondary);}/*!sc*/
# data-styled.g60[id="button-styles__Button-sc-9c115803-1"]{content:"clEXVA,iCWLyT,bIQunG,"}/*!sc*/
# .gdKujf{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;border-radius:50px;border:none;color:var(--xdlColorText);display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-size:14px;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding:0;position:relative;-webkit-text-decoration:none;text-decoration:none;vertical-align:top;z-index:0;color:var(--xdlColorTextOnLight);font-size:14px;height:32px;min-width:32px;padding-inline-end:calc(32px / 2);padding-inline-start:calc(32px / 2);}/*!sc*/
# .gdKujf::after{border-radius:50px;box-sizing:border-box;content:'';cursor:pointer;height:100%;-webkit-inset-block-start:0;-ms-intb-rlock-start:0;inset-block-start:0;inset-inline-start:0;position:absolute;-webkit-transition-duration:150ms;transition-duration:150ms;-webkit-transition-property:-webkit-transform,background-color;-webkit-transition-property:transform,background-color;transition-property:transform,background-color;-webkit-transition-timing-function:cubic-bezier(0,0,0.2,1);transition-timing-function:cubic-bezier(0,0,0.2,1);width:100%;z-index:-100;}/*!sc*/
# .gdKujf:hover,.gdKujf:focus{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .gdKujf:disabled{cursor:default;}/*!sc*/
# .gdKujf:disabled::after{cursor:default;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .gdKujf::after{background-color:var(--xdlColorXING);}/*!sc*/
# .gdKujf:hover{color:var(--xdlColorTextOnLight);}/*!sc*/
# .gdKujf:hover::after{background-color:var(--xdlColorPrimaryButtonHover);color:var(--xdlColorTextOnLight);}/*!sc*/
# @media (hover:none){.gdKujf:hover::after{background-color:var(--xdlColorXING);}}/*!sc*/
# .gdKujf:active{color:var(--xdlColorTextInvert);}/*!sc*/
# .gdKujf:active::after{background-color:var(--xdlColorSelected);color:var(--xdlColorTextInvert);-webkit-transform:scale(0.95);-ms-transform:scale(0.95);transform:scale(0.95);}/*!sc*/
# .gdKujf:disabled{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .gdKujf:disabled::after{background-color:var(--xdlColorDisabledSoft);-webkit-transform:none;-ms-transform:none;transform:none;}/*!sc*/
# .gdKujf[aria-label='loading']::after{background-color:var(--xdlColorXING);}/*!sc*/
# .ioRBLh{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;border-radius:50px;border:none;color:var(--xdlColorText);display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-size:14px;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding:0;position:relative;-webkit-text-decoration:none;text-decoration:none;vertical-align:top;z-index:0;color:var(--xdlColorTextOnLight);font-size:16px;height:42px;min-width:42px;padding-inline-end:calc(42px / 2);padding-inline-start:calc(42px / 2);}/*!sc*/
# .ioRBLh::after{border-radius:50px;box-sizing:border-box;content:'';cursor:pointer;height:100%;-webkit-inset-block-start:0;-ms-intb-rlock-start:0;inset-block-start:0;inset-inline-start:0;position:absolute;-webkit-transition-duration:150ms;transition-duration:150ms;-webkit-transition-property:-webkit-transform,background-color;-webkit-transition-property:transform,background-color;transition-property:transform,background-color;-webkit-transition-timing-function:cubic-bezier(0,0,0.2,1);transition-timing-function:cubic-bezier(0,0,0.2,1);width:100%;z-index:-100;}/*!sc*/
# .ioRBLh:hover,.ioRBLh:focus{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ioRBLh:disabled{cursor:default;}/*!sc*/
# .ioRBLh:disabled::after{cursor:default;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .ioRBLh::after{background-color:var(--xdlColorXING);}/*!sc*/
# .ioRBLh:hover{color:var(--xdlColorTextOnLight);}/*!sc*/
# .ioRBLh:hover::after{background-color:var(--xdlColorPrimaryButtonHover);color:var(--xdlColorTextOnLight);}/*!sc*/
# @media (hover:none){.ioRBLh:hover::after{background-color:var(--xdlColorXING);}}/*!sc*/
# .ioRBLh:active{color:var(--xdlColorTextInvert);}/*!sc*/
# .ioRBLh:active::after{background-color:var(--xdlColorSelected);color:var(--xdlColorTextInvert);-webkit-transform:scale(0.95);-ms-transform:scale(0.95);transform:scale(0.95);}/*!sc*/
# .ioRBLh:disabled{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .ioRBLh:disabled::after{background-color:var(--xdlColorDisabledSoft);-webkit-transform:none;-ms-transform:none;transform:none;}/*!sc*/
# .ioRBLh[aria-label='loading']::after{background-color:var(--xdlColorXING);}/*!sc*/
# data-styled.g61[id="button-styles__RouterButton-sc-9c115803-2"]{content:"gdKujf,ioRBLh,"}/*!sc*/
# .fOcggO{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g62[id="button-styles__InnerContent-sc-9c115803-3"]{content:"fOcggO,"}/*!sc*/
# .kDIpGV{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}/*!sc*/
# data-styled.g64[id="button-styles__Text-sc-9c115803-5"]{content:"kDIpGV,"}/*!sc*/
# .kMIZJx{height:24px;width:24px;margin-inline-end:8px;margin-inline-end:0;margin-inline-start:8px;-webkit-order:1;-ms-flex-order:1;order:1;}/*!sc*/
# .bOVLsA{height:18px;width:18px;margin-inline-end:8px;}/*!sc*/
# .kZXpnE{height:24px;width:24px;margin-inline-end:8px;}/*!sc*/
# .gIBVMB{height:18px;width:18px;margin-inline-end:8px;margin-inline-end:0;margin-inline-start:8px;-webkit-order:1;-ms-flex-order:1;order:1;}/*!sc*/
# data-styled.g69[id="text-button-styles__IconContainer-sc-b5b49a5d-0"]{content:"kMIZJx,bOVLsA,kZXpnE,gIBVMB,"}/*!sc*/
# .efxhDL{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;border:0;color:var(--xdlColorText);display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-size:14px;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding:0;position:relative;-webkit-text-decoration:none;text-decoration:none;vertical-align:top;z-index:0;font-size:16px;height:42px;min-width:42px;overflow:hidden;color:var(--xdlColorText);font-weight:400;padding:0;}/*!sc*/
# .efxhDL::after{box-sizing:border-box;content:'';cursor:pointer;height:100%;-webkit-inset-block-start:0;-ms-intb-rlock-start:0;inset-block-start:0;inset-inline-start:0;position:absolute;-webkit-transition-duration:150ms;transition-duration:150ms;-webkit-transition-property:-webkit-transform,background-color;-webkit-transition-property:transform,background-color;transition-property:transform,background-color;-webkit-transition-timing-function:cubic-bezier(0,0,0.2,1);transition-timing-function:cubic-bezier(0,0,0.2,1);width:100%;z-index:-100;}/*!sc*/
# .efxhDL:active,.efxhDL:hover,.efxhDL:focus{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .efxhDL:disabled{color:var(--xdlColorDisabledStrong);cursor:default;}/*!sc*/
# .efxhDL:disabled::after{cursor:default;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .efxhDL:visited{color:var(--xdlColorText);}/*!sc*/
# .hRgILR{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;border:0;color:var(--xdlColorText);display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-size:14px;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding:0;position:relative;-webkit-text-decoration:none;text-decoration:none;vertical-align:top;z-index:0;font-size:14px;height:32px;min-width:32px;}/*!sc*/
# .hRgILR::after{box-sizing:border-box;content:'';cursor:pointer;height:100%;-webkit-inset-block-start:0;-ms-intb-rlock-start:0;inset-block-start:0;inset-inline-start:0;position:absolute;-webkit-transition-duration:150ms;transition-duration:150ms;-webkit-transition-property:-webkit-transform,background-color;-webkit-transition-property:transform,background-color;transition-property:transform,background-color;-webkit-transition-timing-function:cubic-bezier(0,0,0.2,1);transition-timing-function:cubic-bezier(0,0,0.2,1);width:100%;z-index:-100;}/*!sc*/
# .hRgILR:active,.hRgILR:hover,.hRgILR:focus{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hRgILR:disabled{color:var(--xdlColorDisabledStrong);cursor:default;}/*!sc*/
# .hRgILR:disabled::after{cursor:default;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .hRgILR:visited{color:var(--xdlColorText);}/*!sc*/
# .kJGJOC{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;border:0;color:var(--xdlColorText);display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-size:14px;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding:0;position:relative;-webkit-text-decoration:none;text-decoration:none;vertical-align:top;z-index:0;font-size:14px;height:32px;min-width:32px;color:var(--xdlColorText);font-weight:400;padding:0;}/*!sc*/
# .kJGJOC::after{box-sizing:border-box;content:'';cursor:pointer;height:100%;-webkit-inset-block-start:0;-ms-intb-rlock-start:0;inset-block-start:0;inset-inline-start:0;position:absolute;-webkit-transition-duration:150ms;transition-duration:150ms;-webkit-transition-property:-webkit-transform,background-color;-webkit-transition-property:transform,background-color;transition-property:transform,background-color;-webkit-transition-timing-function:cubic-bezier(0,0,0.2,1);transition-timing-function:cubic-bezier(0,0,0.2,1);width:100%;z-index:-100;}/*!sc*/
# .kJGJOC:active,.kJGJOC:hover,.kJGJOC:focus{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .kJGJOC:disabled{color:var(--xdlColorDisabledStrong);cursor:default;}/*!sc*/
# .kJGJOC:disabled::after{cursor:default;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .kJGJOC:visited{color:var(--xdlColorText);}/*!sc*/
# .ibUtGE{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;border:0;color:var(--xdlColorText);display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-size:14px;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding:0;position:relative;-webkit-text-decoration:none;text-decoration:none;vertical-align:top;z-index:0;font-size:16px;height:42px;min-width:42px;color:var(--xdlColorText);font-weight:400;padding:0;}/*!sc*/
# .ibUtGE::after{box-sizing:border-box;content:'';cursor:pointer;height:100%;-webkit-inset-block-start:0;-ms-intb-rlock-start:0;inset-block-start:0;inset-inline-start:0;position:absolute;-webkit-transition-duration:150ms;transition-duration:150ms;-webkit-transition-property:-webkit-transform,background-color;-webkit-transition-property:transform,background-color;transition-property:transform,background-color;-webkit-transition-timing-function:cubic-bezier(0,0,0.2,1);transition-timing-function:cubic-bezier(0,0,0.2,1);width:100%;z-index:-100;}/*!sc*/
# .ibUtGE:active,.ibUtGE:hover,.ibUtGE:focus{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ibUtGE:disabled{color:var(--xdlColorDisabledStrong);cursor:default;}/*!sc*/
# .ibUtGE:disabled::after{cursor:default;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .ibUtGE:visited{color:var(--xdlColorText);}/*!sc*/
# .gYZviz{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;border:0;color:var(--xdlColorText);display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-size:14px;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding:0;position:relative;-webkit-text-decoration:none;text-decoration:none;vertical-align:top;z-index:0;font-size:16px;height:42px;min-width:42px;color:var(--xdlColorText);font-weight:400;padding:0;padding:0;}/*!sc*/
# .gYZviz::after{box-sizing:border-box;content:'';cursor:pointer;height:100%;-webkit-inset-block-start:0;-ms-intb-rlock-start:0;inset-block-start:0;inset-inline-start:0;position:absolute;-webkit-transition-duration:150ms;transition-duration:150ms;-webkit-transition-property:-webkit-transform,background-color;-webkit-transition-property:transform,background-color;transition-property:transform,background-color;-webkit-transition-timing-function:cubic-bezier(0,0,0.2,1);transition-timing-function:cubic-bezier(0,0,0.2,1);width:100%;z-index:-100;}/*!sc*/
# .gYZviz:active,.gYZviz:hover,.gYZviz:focus{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .gYZviz:disabled{color:var(--xdlColorDisabledStrong);cursor:default;}/*!sc*/
# .gYZviz:disabled::after{cursor:default;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .gYZviz:visited{color:var(--xdlColorText);}/*!sc*/
# .gYZviz .text-button-styles__IconContainer-sc-b5b49a5d-0{margin:0;}/*!sc*/
# data-styled.g70[id="text-button-styles__TextButton-sc-b5b49a5d-1"]{content:"efxhDL,hRgILR,kJGJOC,ibUtGE,gYZviz,"}/*!sc*/
# .bQLXIn{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;border:0;color:var(--xdlColorText);display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-size:14px;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding:0;position:relative;-webkit-text-decoration:none;text-decoration:none;vertical-align:top;z-index:0;font-size:16px;height:42px;min-width:42px;}/*!sc*/
# .bQLXIn::after{box-sizing:border-box;content:'';cursor:pointer;height:100%;-webkit-inset-block-start:0;-ms-intb-rlock-start:0;inset-block-start:0;inset-inline-start:0;position:absolute;-webkit-transition-duration:150ms;transition-duration:150ms;-webkit-transition-property:-webkit-transform,background-color;-webkit-transition-property:transform,background-color;transition-property:transform,background-color;-webkit-transition-timing-function:cubic-bezier(0,0,0.2,1);transition-timing-function:cubic-bezier(0,0,0.2,1);width:100%;z-index:-100;}/*!sc*/
# .bQLXIn:active,.bQLXIn:hover,.bQLXIn:focus{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .bQLXIn:disabled{color:var(--xdlColorDisabledStrong);cursor:default;}/*!sc*/
# .bQLXIn:disabled::after{cursor:default;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .bQLXIn:visited{color:var(--xdlColorText);}/*!sc*/
# data-styled.g71[id="text-button-styles__RouterTextButton-sc-b5b49a5d-2"]{content:"bQLXIn,"}/*!sc*/
# .jjzYgt{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;overflow:hidden;white-space:nowrap;}/*!sc*/
# .dUARzi{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g72[id="text-button-styles__InnerContent-sc-b5b49a5d-3"]{content:"jjzYgt,dUARzi,"}/*!sc*/
# .jdCIxI{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;display:block;max-width:100%;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .hvAMCd{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}/*!sc*/
# data-styled.g74[id="text-button-styles__Text-sc-b5b49a5d-5"]{content:"jdCIxI,hvAMCd,"}/*!sc*/
# .cJLQSp{height:32px;width:32px;position:relative;}/*!sc*/
# .cJLQSp .strokeWidth{stroke-width:1px;}/*!sc*/
# .cJLQSp .strokeWidth{stroke:var(--xdlColorBackgroundTertiary);}/*!sc*/
# .bhpAXy{height:48px;width:48px;position:relative;}/*!sc*/
# .bhpAXy .strokeWidth{stroke-width:1px;}/*!sc*/
# .bhpAXy .strokeWidth{stroke:var(--xdlColorBackgroundTertiary);}/*!sc*/
# @media (min-width:740px){.bhpAXy{height:92px;width:92px;}.bhpAXy .strokeWidth{stroke-width:2px;}}/*!sc*/
# data-styled.g79[id="super-ellipse-styles__SuperEllipse-sc-e6b2f3bc-0"]{content:"cJLQSp,bhpAXy,"}/*!sc*/
# .fBKudO{display:block;height:100%;-webkit-mask-image:url(https://static.xingcdn.com/crate/search-4539e462/super-ellipse-mask-cd22c3b8c137c9902b90787d046b531a.svg);mask-image:url(https://static.xingcdn.com/crate/search-4539e462/super-ellipse-mask-cd22c3b8c137c9902b90787d046b531a.svg);-webkit-mask-position:center;mask-position:center;-webkit-mask-repeat:no-repeat;mask-repeat:no-repeat;position:relative;width:100%;}/*!sc*/
# data-styled.g80[id="super-ellipse-styles__ImageContainer-sc-e6b2f3bc-1"]{content:"fBKudO,"}/*!sc*/
# .ceXFml{aspect-ratio:1 / 1;background-color:var(--xdlColorControlFillSecondary);border-radius:4px;display:block;height:100%;margin:0;padding:0;position:relative;width:100%;z-index:calc(0 - 1);}/*!sc*/
# data-styled.g81[id="super-ellipse-styles__Image-sc-e6b2f3bc-2"]{content:"ceXFml,"}/*!sc*/
# .gxSqgj{height:100%;-webkit-inset-block-end:0;-ms-inlrock-end:0;inset-block-end:0;-webkit-inset-block-start:0;-ms-intb-rlock-start:0;inset-block-start:0;inset-inline-end:0;inset-inline-start:0;margin:auto;padding:0;pointer-events:none;position:absolute;width:100%;z-index:1;}/*!sc*/
# data-styled.g82[id="super-ellipse-styles__ImageSvgBorder-sc-e6b2f3bc-3"]{content:"gxSqgj,"}/*!sc*/
# .glhxXy{display:inline-table;position:relative;height:48px;width:48px;}/*!sc*/
# @media (min-width:740px){.glhxXy{height:92px;width:92px;}}/*!sc*/
# data-styled.g89[id="profile-image-styles__Container-sc-19364873-0"]{content:"glhxXy,"}/*!sc*/
# .fDjzQQ{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g163[id="progress-bar-styles__Container-sc-d578642e-0"]{content:"fDjzQQ,"}/*!sc*/
# .bdsEiN{background-color:var(--xdlColorControlFillTertiary);border-radius:4px;height:6px;overflow:hidden;}/*!sc*/
# data-styled.g164[id="progress-bar-styles__Tracker-sc-d578642e-1"]{content:"bdsEiN,"}/*!sc*/
# .itiyYb{background-color:var(--xdlColorSelected);border-radius:4px;height:6px;width:12.738853503184714%;}/*!sc*/
# data-styled.g165[id="progress-bar-styles__ProgressIndicator-sc-d578642e-2"]{content:"itiyYb,"}/*!sc*/
# .ckQMcH{position:relative;}/*!sc*/
# data-styled.g181[id="input-bar-styles__Wrapper-sc-49e3f47e-0"]{content:"ckQMcH,"}/*!sc*/
# .iQNzRW{-webkit-appearance:none;-moz-appearance:none;appearance:none;display:block;line-height:1.5;resize:none;width:100%;background-color:var(--xdlColorBackground);border-color:transparent;border-style:solid;border-width:1px;color:var(--xdlColorTextTertiary);outline:none;background-color:var(--xdlColorBackground);color:var(--xdlColorText);border-radius:calc(60px / 2);font-size:18px;height:60px;padding-block-start:19px;padding-block-end:19px;padding-inline-end:20px;padding-inline-start:20px;padding-inline-start:calc(20px + 24px + 8px);}/*!sc*/
# .iQNzRW:focus{background-color:var(--xdlColorBackground);border-color:var(--xdlColorBorderStrong);border-width:1px;box-shadow:inset 0 0 0 1px var(--xdlColorBorderStrong);color:var(--xdlColorText);}/*!sc*/
# .iQNzRW:hover{background-color:var(--xdlColorBackground);border-color:var(--xdlColorBorderStrong);border-width:1px;color:var(--xdlColorText);}/*!sc*/
# .iQNzRW::-webkit-input-placeholder{color:var(--xdlColorTextTertiary);font-size:14px;}/*!sc*/
# .iQNzRW::-moz-placeholder{color:var(--xdlColorTextTertiary);font-size:14px;}/*!sc*/
# .iQNzRW:-ms-input-placeholder{color:var(--xdlColorTextTertiary);font-size:14px;}/*!sc*/
# .iQNzRW::placeholder{color:var(--xdlColorTextTertiary);font-size:14px;}/*!sc*/
# .iQNzRW:-ms-input-placeholder{color:var(--xdlColorTextTertiary);font-size:14px;}/*!sc*/
# .iQNzRW[disabled]{background-color:var(--xdlColorDisabledSoft);color:var(--xdlColorDisabledStrong);}/*!sc*/
# .iQNzRW[disabled]::-webkit-input-placeholder{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .iQNzRW[disabled]::-moz-placeholder{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .iQNzRW[disabled]:-ms-input-placeholder{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .iQNzRW[disabled]::placeholder{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .iQNzRW[disabled]:-ms-input-placeholder{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .iQNzRW[disabled]{background-color:var(--xdlColorBackground);color:var(--xdlColorDisabledStrong);}/*!sc*/
# .iQNzRW::-webkit-input-placeholder{font-size:18px;font-weight:500;}/*!sc*/
# .iQNzRW::-moz-placeholder{font-size:18px;font-weight:500;}/*!sc*/
# .iQNzRW:-ms-input-placeholder{font-size:18px;font-weight:500;}/*!sc*/
# .iQNzRW::placeholder{font-size:18px;font-weight:500;}/*!sc*/
# .bmAmAS{-webkit-appearance:none;-moz-appearance:none;appearance:none;display:block;line-height:1.5;resize:none;width:100%;background-color:var(--xdlColorBackground);border-color:transparent;border-style:solid;border-width:1px;color:var(--xdlColorTextTertiary);outline:none;border-radius:calc(60px / 2);font-size:18px;height:60px;padding-block-start:19px;padding-block-end:19px;padding-inline-end:20px;padding-inline-start:20px;padding-inline-start:calc(20px + 24px + 8px);}/*!sc*/
# .bmAmAS:focus{background-color:var(--xdlColorBackground);border-color:var(--xdlColorBorderStrong);border-width:1px;box-shadow:inset 0 0 0 1px var(--xdlColorBorderStrong);color:var(--xdlColorText);}/*!sc*/
# .bmAmAS:hover{background-color:var(--xdlColorBackground);border-color:var(--xdlColorBorderStrong);border-width:1px;color:var(--xdlColorText);}/*!sc*/
# .bmAmAS::-webkit-input-placeholder{color:var(--xdlColorTextTertiary);font-size:14px;}/*!sc*/
# .bmAmAS::-moz-placeholder{color:var(--xdlColorTextTertiary);font-size:14px;}/*!sc*/
# .bmAmAS:-ms-input-placeholder{color:var(--xdlColorTextTertiary);font-size:14px;}/*!sc*/
# .bmAmAS::placeholder{color:var(--xdlColorTextTertiary);font-size:14px;}/*!sc*/
# .bmAmAS:-ms-input-placeholder{color:var(--xdlColorTextTertiary);font-size:14px;}/*!sc*/
# .bmAmAS[disabled]{background-color:var(--xdlColorDisabledSoft);color:var(--xdlColorDisabledStrong);}/*!sc*/
# .bmAmAS[disabled]::-webkit-input-placeholder{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .bmAmAS[disabled]::-moz-placeholder{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .bmAmAS[disabled]:-ms-input-placeholder{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .bmAmAS[disabled]::placeholder{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .bmAmAS[disabled]:-ms-input-placeholder{color:var(--xdlColorDisabledStrong);}/*!sc*/
# .bmAmAS::-webkit-input-placeholder{font-size:18px;font-weight:500;}/*!sc*/
# .bmAmAS::-moz-placeholder{font-size:18px;font-weight:500;}/*!sc*/
# .bmAmAS:-ms-input-placeholder{font-size:18px;font-weight:500;}/*!sc*/
# .bmAmAS::placeholder{font-size:18px;font-weight:500;}/*!sc*/
# data-styled.g182[id="input-bar-styles__Input-sc-49e3f47e-1"]{content:"iQNzRW,bmAmAS,"}/*!sc*/
# .gwuxCa{color:var(--xdlColorText);-webkit-inset-block-start:50%;-ms-intb-rlock-start:50%;inset-block-start:50%;margin-inline-end:8px;position:absolute;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);height:24px;width:24px;color:var(--xdlColorText);inset-inline-start:20px;}/*!sc*/
# [disabled] + .input-bar-styles__IconContainer-sc-49e3f47e-3{color:var(--xdlColorDisabledStrong);}/*!sc*/
# data-styled.g184[id="input-bar-styles__IconContainer-sc-49e3f47e-3"]{content:"gwuxCa,"}/*!sc*/
# .jGwesy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;position:relative;}/*!sc*/
# data-styled.g228[id="super-ellipse-with-badge__SuperEllipseWrapper-sc-22ca9f3-0"]{content:"jGwesy,"}/*!sc*/
# .dXReFU{margin-right:48px;margin-bottom:4px;color:var(--xdlColorText);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;}/*!sc*/
# .dXReFU:hover,.dXReFU:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (max-width:1023px){.dXReFU{margin-right:16px;margin-bottom:0;}}/*!sc*/
# data-styled.g230[id="activity-center-button__StyledLink-sc-74e5f4cc-0"]{content:"dXReFU,"}/*!sc*/
# .fwnTcR{margin:0;-webkit-text-decoration:none;text-decoration:none;text-align:left;}/*!sc*/
# @media (max-width:1023px){.fwnTcR{display:none;}}/*!sc*/
# data-styled.g231[id="activity-center-button__StyledTitle-sc-74e5f4cc-1"]{content:"fwnTcR,"}/*!sc*/
# .cZrsEw > div{padding-bottom:12px;padding-left:16px;padding-right:16px;padding-top:12px;}/*!sc*/
# data-styled.g238[id="menu-styles__BottomSheet-sc-cdad8155-1"]{content:"cZrsEw,"}/*!sc*/
# .ddpsOU{max-height:90vh;min-width:288px;overflow:auto;}/*!sc*/
# @media (min-width:740px){.ddpsOU{max-height:556px;position:absolute;top:48px;right:-5px;}}/*!sc*/
# data-styled.g243[id="business-solutions-menu-styles__StyledMenu-sc-7308473a-1"]{content:"ddpsOU,"}/*!sc*/
# .bGXUnZ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;position:relative;}/*!sc*/
# data-styled.g244[id="icon-with-badge__StyledIconWrapper-sc-def5423-0"]{content:"bGXUnZ,"}/*!sc*/
# .eWKytU{-webkit-flex:0 0 24px;-ms-flex:0 0 24px;flex:0 0 24px;height:24px;width:24px;}/*!sc*/
# data-styled.g246[id="icon-with-badge__IconWithBadge-sc-def5423-2"]{content:"eWKytU,"}/*!sc*/
# .bnEJOe{border-radius:8px;height:28px;width:42px;-webkit-flex:0 0 42px;-ms-flex:0 0 42px;flex:0 0 42px;}/*!sc*/
# .bnEJOe:hover{background-color:var(--xdlColorHover);}/*!sc*/
# data-styled.g247[id="nav-item-header-logged-out-styles__StyledIconWithBadge-sc-c1539db8-0"]{content:"bnEJOe,"}/*!sc*/
# .kVIGIt{margin-right:48px;color:var(--xdlColorText);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;}/*!sc*/
# @media (min-width:740px) and (max-width:1267px){.kVIGIt{border-radius:4px;margin-bottom:0;}}/*!sc*/
# .kVIGIt:active .nav-item-header-logged-out-styles__StyledIconWithBadge-sc-c1539db8-0{background-color:var(--xdlColorHoverSecondary);}/*!sc*/
# .kVIGIt:hover,.kVIGIt:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# data-styled.g248[id="nav-item-header-logged-out-styles__StyledLink-sc-c1539db8-1"]{content:"kVIGIt,"}/*!sc*/
# .jYFApF{margin:0;-webkit-text-decoration:none;text-decoration:none;text-align:left;}/*!sc*/
# data-styled.g249[id="nav-item-header-logged-out-styles__StyledTitle-sc-c1539db8-2"]{content:"jYFApF,"}/*!sc*/
# .jSYCSx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:var(--xdlPalettePetrol10);height:100%;width:100%;}/*!sc*/
# data-styled.g253[id="logo-styles__StyledButterfly-sc-3103173b-0"]{content:"jSYCSx,"}/*!sc*/
# .jorEmH{padding-top:4px;}/*!sc*/
# data-styled.g254[id="logo-styles__StyledXingLogo-sc-3103173b-1"]{content:"jorEmH,"}/*!sc*/
# .fECakB{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:var(--xdlColorTextInvert);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;height:100%;}/*!sc*/
# data-styled.g255[id="logo-styles__StyledLink-sc-3103173b-2"]{content:"fECakB,"}/*!sc*/
# .eDTKoA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;max-width:2136px;padding-left:0;padding-right:0;width:100%;}/*!sc*/
# @media (min-width:740px){.eDTKoA{padding-left:18px;padding-right:18px;}}/*!sc*/
# @media (min-width:1024px){.eDTKoA{padding-left:18px;padding-right:18px;}}/*!sc*/
# @media (min-width:1113px){.eDTKoA{padding-left:32px;padding-right:32px;}}/*!sc*/
# @media (min-width:1440px){.eDTKoA{padding-left:60px;padding-right:60px;}}/*!sc*/
# @media (min-width:1680px){.eDTKoA{padding-left:66px;padding-right:66px;}}/*!sc*/
# @media (min-width:1920px){.eDTKoA{margin:auto;padding-left:72px;padding-right:72px;}}/*!sc*/
# data-styled.g259[id="center-container__StyledContainer-sc-cdb33bf6-0"]{content:"eDTKoA,"}/*!sc*/
# @media (min-width:1024px){.ZzrVU{display:none;}}/*!sc*/
# @media (max-width:1023px){.jSoZbp{display:none;}}/*!sc*/
# data-styled.g260[id="header-logged-out-styles__StyledButtonSmallWhenTopBar-sc-d5d5fe85-0"]{content:"ZzrVU,jSoZbp,"}/*!sc*/
# .ddgXVb{height:calc(84px);}/*!sc*/
# @media (max-width:1023px){.ddgXVb{height:calc(54px);}}/*!sc*/
# data-styled.g261[id="header-logged-out-styles__StyledPlacebo-sc-d5d5fe85-1"]{content:"ddgXVb,"}/*!sc*/
# ...
# @media (prefers-color-scheme:dark){:root{--xdlColorBackground:#161C24;--xdlColorBackgroundDark:#161C24;--xdlColorBackgroundLight:#FFFFFF;--xdlColorBackgroundSecondary:#212A36;--xdlColorBackgroundTertiary:#293545;--xdlColorBeta:#F34B65;--xdlColorBorder:#8A9DA6;--xdlColorBorderSoft:#414D5D;--xdlColorBorderStrong:#FFFFFF;--xdlColorButtonSecondaryHover:rgba(138,157,166,0.40);--xdlColorButtonStrong:#C6F16D;--xdlColorButtonStrongHover:#A7E770;--xdlColorCardHero01:#F7F2EB;--xdlColorCardHero02:#BD85FB;--xdlColorCardHero03:#E8D5FF;--xdlColorCardHero04:#46B7BB;--xdlColorCardHero05:#BBE7E8;--xdlColorCardHero06:#CAD3E2;--xdlColorCardHero07:#F5AE87;--xdlColorCardHero08:#91D5C2;--xdlColorCardInspireText01:#1D2124;--xdlColorCardInspireText02:#1D2124;--xdlColorCardInspireText03:#1D2124;--xdlColorCardInspire01:#91D5C2;--xdlColorCardInspire02:#BBE7E8;--xdlColorCardInspire03:#E8D5FF;--xdlColorCardInspire04:#BD85FB;--xdlColorCardInspire05:#46B7BB;--xdlColorCardInspire06:#CAD3E2;--xdlColorCardInspire07:#F5AE87;--xdlColorCaution:#FE7C62;--xdlColorChart01:#00D296;--xdlColorChart02:#0698A0;--xdlColorChart03:#C6F16D;--xdlColorChart04:#97B7F7;--xdlColorChart05:#FF847E;--xdlColorChart06:#9569AB;--xdlColorChart07:#D4699E;--xdlColorChart08:#BCC9D1;--xdlColorChart09:#F4164D;--xdlColorControlBorder:#616D7D;--xdlColorControlBorderSecondary:#FFFFFF;--xdlColorControlBorderTertiary:#161C24;--xdlColorControlFill:#161C24;--xdlColorControlFillQuaternary:#161C24;--xdlColorControlFillSecondary:#F4F4F5;--xdlColorControlFillTertiary:#616D7D;--xdlColorDimming:#000000;--xdlColorDisabled:#435057;--xdlColorDisabledSoft:#414D5D;--xdlColorDisabledStrong:#616D7D;--xdlColorError:#F34B65;--xdlColorErrorSoft:#F8DDDF;--xdlColorFocussed:#0698A0;--xdlColorGo:#00C48C;--xdlColorHighlighted:#87D34A;--xdlColorHover:#293545;--xdlColorHoverQuaternary:#BCC9D1;--xdlColorHoverSecondary:#435057;--xdlColorHoverTertiary:#414D5D;--xdlColorInfo:#97B7F7;--xdlColorInfoSoft:#1C4FB8;--xdlColorLink:#0698A0;--xdlColorLinkHover:#007B80;--xdlColorLinkVisited:#7C8A9C;--xdlColorMarkerHighlight:#293545;--xdlColorMarkerHighlightText:#BD85FB;--xdlColorMarkerMatch:#293545;--xdlColorMarkerMatchText:#06A7AC;--xdlColorMarkerStrong:#8A2CE8;--xdlColorMeHubAssessmentHighlight:#293545;--xdlColorMeHubHighlight:#293545;--xdlColorMenuHighlight:#212A36;--xdlColorMenuHighlightHover:#293545;--xdlColorMenuHighlightPressed:#414D5D;--xdlColorMenuPressed:#414D5D;--xdlColorMenuStrong:#551D86;--xdlColorMenuStrongHover:#6822A7;--xdlColorMenuStrongPressed:#7A23CD;--xdlColorModalBorder:#414D5D;--xdlColorNew:#F34B65;--xdlColorNewListItemSoft:#212A36;--xdlColorNotification:#F34B65;--xdlColorPollIndicatorPrimary:#009C77;--xdlColorPollIndicatorSecondary:#414D5D;--xdlColorPremium:#0698A0;--xdlColorPremiumSecondary:#007B80;--xdlColorPremiumTertiary:#293545;--xdlColorPricing:#9C195B;--xdlColorPrimaryButtonHover:#A7E770;--xdlColorProBusiness:#9569AB;--xdlColorProBusinessQuaternary:#E1CFEE;--xdlColorProBusinessSecondary:#85599B;--xdlColorProBusinessTertiary:#293545;--xdlColorProJobs:#009A84;--xdlColorProJobsFill:#27DBA8;--xdlColorProJobsSecondary:#00D296;--xdlColorProJobsTertiary:#293545;--xdlColorProgressBadgeBackground01:#FE9A95;--xdlColorProgressBadgeBackground02:#FFDA5F;--xdlColorProgressBadgeBackground03:#CBF576;--xdlColorProgressBadgeBackground04:#27DBA8;--xdlColorSelected:#FFFFFF;--xdlColorSelectedSecondary:#0698A0;--xdlColorSelectedTertiary:#84D4D5;--xdlColorSkeletonPrimary:#293545;--xdlColorSkeletonPrimaryAnimation:#414D5D;--xdlColorSkeletonSecondary:#616D7D;--xdlColorSkeletonSecondaryAnimation:#7C8A9C;--xdlColorSliderTickMark:#7C8A9C;--xdlColorStop:#F34B65;--xdlColorSuccess:#00C48C;--xdlColorSuccessSoft:#007C5F;--xdlColorText:#FFFFFF;--xdlColorTextInvert:#1D2124;--xdlColorTextOnDark:#FFFFFF;--xdlColorTextOnLight:#1D2124;--xdlColorTextSecondary:#BCC9D1;--xdlColorTextSecondaryOnDark:#BCC9D1;--xdlColorTextSecondaryOnLight:#5E737D;--xdlColorTextTertiary:#5E737D;--xdlColorTextTertiaryOnDark:#5E737D;--xdlColorTextTertiaryOnLight:#8A9D ...
# data-styled.g3167[id="sc-global-dzeqQu2"]{content:"sc-global-dzeqQu2,"}/*!sc*/
# @-webkit-keyframes cfkuO{0%{background-color:var(--xdlColorSkeletonPrimaryAnimation);}100%{background-color:var(--xdlColorSkeletonPrimary);}}/*!sc*/
# @keyframes cfkuO{0%{background-color:var(--xdlColorSkeletonPrimaryAnimation);}100%{background-color:var(--xdlColorSkeletonPrimary);}}/*!sc*/
# data-styled.g3169[id="sc-keyframes-cfkuO"]{content:"cfkuO,"}/*!sc*/
# @-webkit-keyframes xdnOO{0%{fill:var(--xdlColorSkeletonPrimaryAnimation);}100%{fill:var(--xdlColorSkeletonPrimary);}}/*!sc*/
# @keyframes xdnOO{0%{fill:var(--xdlColorSkeletonPrimaryAnimation);}100%{fill:var(--xdlColorSkeletonPrimary);}}/*!sc*/
# data-styled.g3171[id="sc-keyframes-xdnOO"]{content:"xdnOO,"}/*!sc*/
# </style>
# </head>
# <body >
# <div id="app" data-mountpoint >
# <div style="outline:none" tabindex="-1"><div class="om-view-animation__StyledOmViewPortalTarget-sc-42482f15-0 bBtLgn"></div><div><div style="outline:none" tabindex="-1"><div><section class="section__Section-sc-b7df443b-0 section__BackgroundSection-sc-b7df443b-1 container-styles__Background-sc-48658ac9-0 jHJcmV eEeoZI ienkgQ"><div class="header-logged-out-styles__StyledPlacebo-sc-d5d5fe85-1 ddgXVb"><header class="header-logged-out-styles__StyledHeaderWrapper-sc-d5d5fe85-2 fjMRys"><div class="center-container__StyledContainer-sc-cdb33bf6-0 eDTKoA header-logged-out-styles__StyledHeader-sc-d5d5fe85-3 gCBvRh"><div class="header-logged-out-styles__StyledLogoWrapper-sc-d5d5fe85-4 bYLDwB"><a title="Zur XING Startseite" class="logo-styles__StyledLink-sc-3103173b-2 fECakB header-logged-out-styles__StyledLogo-sc-d5d5fe85-5 gDzcDD" data-qa="logoMobile"><div class="butterfly-styles__Butterfly-sc-d3b25798-0 cTztx logo-styles__StyledButterfly-sc-3103173b-0 jSYCSx" data-xds="Butterfly"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 28 31" data-xds="LogoXINGButterflyDuo" height="31" width="28"><g fill-rule="evenodd" clip-path="url(#clip0_47_1357)" clip-rule="evenodd"><path fill="#0698A0" d="m1.81 5.986 3.655 6.479L0 22.021h6.515l5.429-9.556-3.656-6.479z"></path><path fill="#B7DF4B" d="M21.207 0 10.67 18.644 17.464 31h6.615l-6.905-12.356L27.713 0z"></path></g><defs><clipPath id="clip0_47_1357"><path fill="#fff" d="M0 0h28v31H0z"></path></clipPath></defs></svg></div></a><a title="Zur XING Startseite" class="logo-styles__StyledLink-sc-3103173b-2 fECakB header-logged-out-styles__StyledLogo-sc-d5d5fe85-5 gPiHVf" data-qa="logo"><div class="xing-logo-styles__XingLogo-sc-6d1be927-0 eGzMWs logo-styles__StyledXingLogo-sc-3103173b-1 jorEmH" data-xds="XingLogo"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 106 31" data-xds="LogoXINGLogoDuo" height="28" width="96"><g fill-rule="evenodd" clip-path="url(#clip0_47_1328)" clip-rule="evenodd"><path fill="#0698A0" d="m1.805 5.984 3.635 6.479L0 22.018h6.491l5.4-9.555-3.634-6.48z"></path><path fill="#B7DF4B" d="m21.122 0-10.49 18.642L17.396 31h6.582l-6.88-12.358L27.6 0z"></path><path fill="#0698A0" d="m40.505 2.998 3.777 7.979 4.129-7.979h5.387l-6.608 11.98 6.868 13.024h-5.647l-4.245-8.734-4.207 8.734h-5.426l6.543-12.958-6.258-12.046zm16.578 25.004h5.245V2.998h-5.245zm48.904-14.353h-8.672v4.315h3.869V23.4a6.6 6.6 0 0 1-2.61.508c-3.972 0-5.621-2.985-5.621-8.304 0-4.966 1.428-8.564 6.127-8.564 1.571 0 3.298.43 4.986 1.186l1.506-3.99c-2.078-1.081-4.336-1.55-6.7-1.55-7.698 0-11.1 4.862-11.1 12.88 0 8.199 3.26 12.775 10.815 12.775 2.441 0 4.907-.509 7.413-1.695V13.649zM71.26 2.999h-4.414v25.003h5.102V13.857l8.412 14.145h4.271V2.998H79.53v14.145z"></path></g><defs><clipPath id="clip0_47_1328"><path fill="#fff" d="M0 0h106v31H0z"></path></clipPath></defs></svg></div></a></div><nav data-qa="loggedOut-nav" class="header-logged-out-styles__StyledNav-sc-d5d5fe85-6 eRcLCB"><div class="header-logged-out-styles__StyledNavItemContainer-sc-d5d5fe85-7 cMRveO"><div class="conditionals__OnlyOnLarge-sc-54c4fd56-2 emiGcc"><a href="/" data-qa="frame-vnav-jobs" class="nav-item-header-logged-out-styles__StyledLink-sc-c1539db8-1 kVIGIt"><div class="icon-with-badge__StyledIconWrapper-sc-def5423-0 bGXUnZ"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 24 24" data-xds="IconJobs" class="icon-with-badge__IconWithBadge-sc-def5423-2 nav-item-header-logged-out-styles__StyledIconWithBadge-sc-c1539db8-0 eWKytU bnEJOe" aria-label="Jobs finden"><path fill="currentColor" d="M12 3a5 5 0 0 1 4.9 4H21v14H3V7h4.1A5 5 0 0 1 12 3m-1 11H5v5h14v-5h-6v2h-2zm8-5H5v3h14zm-7-4a3 3 0 0 0-2.83 2h5.66A3 3 0 0 0 12 5"></path></svg></div><p class="nav-item-header-logged-out-styles__StyledTitle-sc-c1539db8-2 jYFApF">Jobs finden</p></a></div><div class="conditionals__OnlyOnLarge-sc-54c4fd56-2 emiGcc"><a href="/companies" data-qa="frame-vnav-companies" class="nav-item-header-logged-out-styles__StyledLink-sc-c1539db8- ...
# </div>
# <script id="runtime-config">window.crate={"assetsBaseUrl":"https:\u002F\u002Fstatic.xingcdn.com\u002Fcrate","basePath":"\u002F","enableMocks":false,"entryPoint":"@xing-com\u002Fcrate-communication-root","isPreview":false,"loginAppUrl":"https:\u002F\u002Flogin.xing.com\u002F","manifestId":"fa036accfaa7e5a9d1ecd5bad6a680b8019c8beb","xingOneEndpoint":"https:\u002F\u002Fwww.xing.com\u002Fgraphql\u002Fapi","isWebview":false,"deviceInfo":{"isAndroid":false,"isIOS":false,"mobileProtocol":"","profileUrlMobile":""},"activeThemeCookie":undefined,"dataDog":{"applicationId":"7a7477f0-2b32-421c-b37c-ab8096323dac","clientToken":"pub61ca6c80a2502896485765ab458bd6e6","sessionSampleRate":1,"version":"fa036accfaa7e5a9d1ecd5bad6a680b8019c8beb"},"language":"de","loginState":"LOGGED_OUT","mockSessionId":undefined,"serverData":{"APOLLO_STATE":{"Viewer:0.22fe30":{"__typename":"Viewer","id":"0.22fe30","jobRecentSearches({\"consumer\":\"loggedin.web.jobs.search\",\"limit\":5})":null,"featureSwitchesExperiments({\"names\":[\"ABACUS-157\",\"ABACUS-387\",\"ABACUS-388\",\"ABACUS-418\",\"ABACUS-425\",\"ABACUS-426\",\"ABACUS-439\",\"ABACUS-446\",\"ABACUS-451\",\"ABACUS-452\",\"ABACUS-458\"]})":null},"ROOT_QUERY":{"__typename":"Query","viewer":{"__ref":"Viewer:0.22fe30"},"featureSwitchesLoggedOutExperiments({\"identifier\":\"f6d3b7a1-9204-404d-812a-254bc3d78e5d\",\"names\":[\"ABACUS-443\",\"ABACUS-448\",\"ABACUS-456\",\"CMP-141\"]})":{"__typename":"FeatureSwitchesExperimentsCollection","collection":[{"__typename":"FeatureSwitchesExperiment","name":"ABACUS-443","variant":"B"},{"__typename":"FeatureSwitchesExperiment","name":"ABACUS-448","variant":"A"},{"__typename":"FeatureSwitchesExperiment","name":"ABACUS-456","variant":"A"}]},"jobSearchByQuery({\"consumer\":\"loggedout.web.jobs.search_results.center\",\"limit\":20,\"offset\":0,\"query\":{\"keywords\":\"Mathematiker\",\"extractedFilter\":{}},\"returnAggregations\":true,\"searchMode\":\"NORMAL\",\"sort\":null,\"splitBenefit\":true,\"trackRecent\":true})":{"__typename":"JobSearchResult","total":157,"searchQuery":{"__typename":"JobSearchQuery","guid":"9e84e94a22c26b4f4a24879c7f3caaf5","body":{"__typename":"JobSearchQueryBody","keywords":"Mathematiker","location":null,"filterCollection":null,"extractedFilter":null}},"appliedFilters":null,"collection":[{"__typename":"JobItemResult","trackingToken":"f9378f9984c011efac745e8e1eafd1d9.0.125591620","position":0,"descriptionHighlight":null,"jobDetail":{"__ref":"VisibleJob:125591620.23792a"},"matchingHighlightsV2":{"__typename":"JobMatchingHighlightsV2","token":"f9378f9984c011efac745e8e1eafd1d9.0.125591620","highlight":{"__typename":"JobMatchingHighlightsJobHighlightV2","type":"job_highlight_early_applicant","localization":{"__typename":"JobMatchingHighlightsLocalizableV2","localizationValue":"Zu den Ersten gehÃ¶ren"},"localizationA11y":{"__typename":"JobMatchingHighlightsLocalizableV2","localizationValue":"Zu den Ersten gehÃ¶ren"}},"matchingFacts":[],"nonMatchingFacts":[{"__typename":"JobMatchingHighlightsJobKeyfactStringV2","type":"job_keyfact_employment_type","localization":{"__typename":"JobMatchingHighlightsLocalizableV2","localizationValue":"Teilzeit"},"localizationA11y":{"__typename":"JobMatchingHighlightsLocalizableV2","localizationValue":"Teilzeit"}},{"__typename":"JobMatchingHighlightsJobKeyfactSalaryV2","type":"job_keyfact_salary","localization":{"__typename":"JobMatchingHighlightsLocalizableV2","localizationValue":"EUR 50500 - EUR 67000"},"localizationA11y":{"__typename":"JobMatchingHighlightsLocalizableV2","localizationValue":"EUR 50500 - EUR 67000"},"value":{"__typename":"SalaryRange","currency":"EUR","minimum":50500,"maximum":67000}}]}},{"__typename":"JobItemResult","trackingToken":"f9378f9984c011efac745e8e1eafd1d9.1.125606686","position":1,"descriptionHighlight":null,"jobDetail":{"__ref":"VisibleJob:125606686.3757f5"},"matchingHighlightsV2":{"__typename":"JobMatchingHighlightsV2","token":"f9378f9984c011efac745e8e1eafd1d9.1.125606686","highlight":{"__typ ...
# <script id="server-data">window._hopsServerData={"authenticated":false,"hopsVersion":"v14.2.4-crate","language":"de","loginState":"LOGGED_OUT","loginUrl":"https:\u002F\u002Flogin.xing.com\u002F","logjamAction":"jobs::$slug#get","logjamRequestId":"crate-production-9e4a9f8d07e24142a84e4be9e9cfca2f"}</script>
#
#
# </body>
# </html>

# %%
# Aus dem Inspector rausgeholt (via copy inner HTML
html2 = """
<li class="css-5lfssm eu4oa1w0"><!--$--><div class="cardOutline tapItem dd-privacy-allow result job_4502c46a336fc4de sponsoredJob resultWithShelf sponTapItem desktop css-1fgwmc eu4oa1w0"><div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container"><div class="slider_list css-ltdjbe eu4oa1w0"><div data-testid="slider_item" class="slider_item css-mk9n32 eu4oa1w0"><div data-testid="fade-in-wrapper" class="css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation" cellspacing="0" cellpadding="0"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><div class="css-dekpa e37uo190"><h2 class="jobTitle css-198pbd eu4oa1w0" tabindex="-1"><a id="sj_4502c46a336fc4de" data-mobtk="1i9b4s6e8h63o83p" data-jk="4502c46a336fc4de" data-ci="436760225" data-empn="2920466863573314" data-hiring-event="false" data-hide-spinner="true" role="button" aria-label="Alle Details zu IT-Affiner Physiker (m/w/d), Mathematiker (m/w/d) oder Ingenieur (m/w/d), vorzugsweise mit Promotion" class="jcs-JobTitle css-jspxzf eu4oa1w0" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0DSpxI5zDNl4WQEdEtw9Dpu3V6Z6qMMzWV4a_YE7Ej7_ViqpJxwFBZQ5XXTRdZeWG3xXKF9o_iUGMuajO9HqE1oIqQF0us1YmyV8RGRb9UkzumLtOfDq_GV399q1YrY70e9BRetcYqGmKNfOTc-OGfW5-Zw87lgui7_OgglwDZoaVg4ow-dPwLA5oosaBWL8x85vPoRdSZ_7J-a9d_Imo8FkVPLyMFsRZ9gn2br96bW_Pe83OcJgjSZV5RKFNsEGhk6i8EQHnP3XGbXSg5Oa_RNL8awawdrTxPzL6Fs97OKokuKhRG4hswj0PNYnIIS_EmlqRgRivaAxPWiuxwiNFR82CzObAqGHZGqmfDl7ETB8c6eFylxmCVXQBSFEHQChQFYLw7_v-StOahui0oCL8zDf299pJXDOcjlZINt7mBcQn8pbSTGvyhZr1Zq7UiiAU6Qpx0-irC4AfsZK6u-BK08vMNgDHE3AALRfMjzxo9n7b3D04xfRokyoOzTBox0NMvPLbHAp8EIlgBqvjtOOSvT-HN-29nfWSaE60vRIU6ippo8tdUHZDmZPuaotC0DT6LdXfqq_B0iSBApShyRo9RhhXq8fPZAYIDUHWHIIaldUqyW0uMpqqo-iPmNoCQuOlR5sk1k-D-PLMBVFesubeRvHsqIuW5-T_2iW82TFFc2JsbjDVJMo3D-0qrt-790R0mP05NGsddOcXCdh7u7C0X3JzZgdNTXHCwXeI7kfqIfY7fkGEKlsGJ7vBvoHiSFQDwRxx4SCRa_HxStxuopjcSTlXIUmkp2ZRNOVSdsZorKf8QMqBKyBbLvlDz0MZfdKPHhYDNaCr68gosSM0uONlgV1oh1p_Mi5dwPHlTQGEBkgrYJXlZH3Iixr9L8Yjxcjf4=&amp;xkcb=SoA-6_M37rB_CUTZoh0LbzkdCdPP&amp;camk=nUmJqO2E8rgIprVE48XK7g==&amp;p=0&amp;fvj=0&amp;vjs=3"><span title="IT-Affiner Physiker (m/w/d), Mathematiker (m/w/d) oder Ingenieur (m/w/d), vorzugsweise mit Promotion" id="jobTitle-4502c46a336fc4de">IT-Affiner Physiker (m/w/d), Mathematiker (m/w/d) oder Ingenieur (m/w/d), vorzugsweise mit Promotion</span></a></h2><div class="css-1hlnck6 e37uo190"></div></div><div class="company_location css-17fky0v e37uo190"><div elementtiming="significant-render" data-testid="timing-attribute"><div class="css-1qv0295 e37uo190"><span data-testid="company-name" class="css-63koeb eu4oa1w0">Diehl Group</span><span class="css-1q5aiuj eu4oa1w0"><span aria-label="3,8 out of five stars rating" role="img" data-testid="holistic-rating" class="css-3l02cv eu4oa1w0"><span aria-hidden="true">3,8</span><span class="css-1nc1e2q eu4oa1w0"><svg width="12" height="12" role="presentation" aria-hidden="true" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M8 12.8709L12.4542 15.5593C12.7807 15.7563 13.1835 15.4636 13.0968 15.0922L11.9148 10.0254L15.8505 6.61581C16.1388 6.36608 15.9847 5.89257 15.6047 5.86033L10.423 5.42072L8.39696 0.640342C8.24839 0.289808 7.7516 0.289808 7.60303 0.640341L5.57696 5.42072L0.395297 5.86033C0.015274 5.89257 -0.13882 6.36608 0.149443 6.61581L4.0852 10.0254L2.90318 15.0922C2.81653 15.4636 3.21932 15.7563 3.54584 15.5593L8 12.8709Z" fill="#767676"></path></svg></span></span></span></div><div data-testid="text-location" class="css-1p0sjhy eu4oa1w0">Überlingen</div></div></div><div class="jobMetaDataGroup css-pj786l eu4oa1w0"><div class="heading6 tapItem-gutter metadataContainer css-z5ecg7 eu4oa1w0"><div class="metadata css-5zy3wz eu4oa1w0"><div data-testid="attribute_snippet_testid" class="css-1cvvo1b eu4oa1w0">Vollzeit<span class="more-items css-77pif9 eu4oa1w0" data-testid="more-items"> <!-- -->+<!-- -->1</span></div></div></div><div class="heading6 error-text tapItem-gutter"></div></div></td><td class="css-biqn32 eu4oa1w0"><button aria-haspopup="true" title="More" aria-label="Job actions for IT-Affiner Physiker (m/w/d), Mathematiker (m/w/d) oder Ingenieur (m/w/d), vorzugsweise mit Promotion is collapsed" class="e8ju0x51 mosaic-provider-jobcards-1kkwgax ex6cvhv1" id="jobActionButton-4502c46a336fc4de" type="button" data-reach-menu-button=""><svg xmlns="http://www.w3.org/2000/svg" focusable="false" role="img" fill="currentColor" viewBox="0 0 24 24" aria-hidden="true" class="mosaic-provider-jobcards-1luvpuv eac13zx0"><path d="M12 7c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 3c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 7c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></button></td></tr></tbody></table><div role="presentation" class="css-1u8dvic eu4oa1w0"><div class="underShelfFooter"><div class="heading6 tapItem-gutter css-1rgici5 eu4oa1w0"><div class="css-9446fg eu4oa1w0"><ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
 <li>Sie arbeiten in einem interdisziplinären Team an der Konzeptionierung und Umsetzung der operationellen Software von hochkomplexen Flugkörpersystemen und stimmen…</li>
</ul></div><span>Anzeige</span><span class="css-opxvw7 eu4oa1w0">·</span><span data-testid="myJobsStateDate" class="css-qvloho eu4oa1w0"><span class="css-10pe3me eu4oa1w0">Employer</span>Aktiv: vor 4 Tagen</span></div></div></div><a rel="nofollow" class="more_loc css-1dwagx2 eu4oa1w0" href="/addlLoc/redirect?tk=1i9b4s6e8h63o83p&amp;jk=4502c46a336fc4de&amp;dest=%2Fjobs%3Fq%3Dmathematiker%26grpKey%3D8gcFdG5mZWy4D7jG2QaqEBcKCW5vcm10aXRsZRoKaXQgbWFuYWdlcg%253D%253D" aria-label="Ähnliche Stellenanzeigen von diesem Arbeitgeber anzeigen">Ähnliche Stellenanzeigen von diesem Arbeitgeber anzeigen</a><div class="ctaContainer"></div><div aria-live="polite"></div></div></div></div></div></div></div><span aria-live="polite" class="visually-hidden css-10pe3me eu4oa1w0"></span><!--/$--></li>
"""

# Beispielcode zum rausparsen 
from bs4 import BeautifulSoup # screen-scraping 
import json

# Parse the HTML
soup = BeautifulSoup(html, 'html.parser')

# Extract relevant job details
job_card = soup.find('li', class_='css-5lfssm')

# Job details
job_title = job_card.find('span', {'id': lambda x: x and x.startswith('jobTitle')}).get_text(strip=True)
company_name = job_card.find('span', {'data-testid': 'company-name'}).get_text(strip=True)
location = job_card.find('div', {'data-testid': 'text-location'}).get_text(strip=True)
rating = job_card.find('span', {'data-testid': 'holistic-rating'}).get_text(strip=True)
job_type = job_card.find('div', {'data-testid': 'attribute_snippet_testid'}).get_text(strip=True)
posted_date = job_card.find('span', {'data-testid': 'myJobsStateDate'}).get_text(strip=True)

# Extracting job description points (if present)
job_description_items = job_card.find_all('li')
job_description = [item.get_text(strip=True) for item in job_description_items]

# Structured JSON format
job_details = {
    "job_title": job_title,
    "company_name": company_name,
    "location": location,
    "rating": rating,
    "job_type": job_type,
    "posted_date": posted_date,
    "job_description": job_description
}

# Convert to JSON string for output
job_details_json = json.dumps(job_details, indent=4, ensure_ascii=False)
print(job_details_json)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 19
#      16 job_card = soup.find('li', class_='css-5lfssm')
#      18 # Job details
# ---> 19 job_title = job_card.find('span', {'id': lambda x: x and x.startswith('jobTitle')}).get_text(strip=True)
#      20 company_name = job_card.find('span', {'data-testid': 'company-name'}).get_text(strip=True)
#      21 location = job_card.find('div', {'data-testid': 'text-location'}).get_text(strip=True)
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
# Beispielcode um das zu umgehen

# Zuerst kopiert man via Inspector den ganzen code raus:
with open('htmltesttext.txt', 'r') as file:
    html2 = file.read()  # Den gesamten Inhalt der Datei in eine Variable speichern
    
from bs4 import BeautifulSoup
import json

def extract_all_job_details(html: str) -> str:
    # Parse the HTML
    soup = BeautifulSoup(html, 'html.parser')

    # Find all relevant job cards
    job_cards = soup.find_all('li', class_='css-5lfssm')

    if not job_cards:
        return json.dumps({"error": "No job cards found"}, indent=4, ensure_ascii=False)

    all_job_details = []

    for job_card in job_cards:
        try:
            # Extract job details
            job_title = job_card.find('span', {'id': lambda x: x and x.startswith('jobTitle')}).get_text(strip=True)
            company_name = job_card.find('span', {'data-testid': 'company-name'}).get_text(strip=True)
            location = job_card.find('div', {'data-testid': 'text-location'}).get_text(strip=True)
            rating = job_card.find('span', {'data-testid': 'holistic-rating'}).get_text(strip=True)
            job_type = job_card.find('div', {'data-testid': 'attribute_snippet_testid'}).get_text(strip=True)
            posted_date = job_card.find('span', {'data-testid': 'myJobsStateDate'}).get_text(strip=True)
            #.find('div').find('p')

            # Extract job description points
            job_description_items = job_card.find_all('li')
            job_description = [item.get_text(strip=True) for item in job_description_items]

            # Structure the extracted data
            job_details = {
                "job_title": job_title,
                "company_name": company_name,
                "location": location,
                "rating": rating,
                "job_type": job_type,
                "posted_date": posted_date,
                "job_description": job_description
            }

            all_job_details.append(job_details)

        except AttributeError:
            # Handle cases where a job card is incomplete
            all_job_details.append({"error": "Failed to parse some job details for this card"})

    # Convert all job details to JSON
    return json.dumps(all_job_details, indent=4, ensure_ascii=False)

# Beispielaufruf der Funktion
result = extract_all_job_details(html)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 232
#     229     return json.dumps(all_job_details, indent=4, ensure_ascii=False)
#     231 # Beispielaufruf der Funktion
# --> 232 result = extract_all_job_details(html)
#     233 print(result)
#
# NameError: name 'html' is not defined

# %%
url = "https://www.xing.com/jobs/search?sc_o=losp_jobs_search_button_click&sc_o_PropActionOrigin=losp_job_search&keywords=Mathematiker&id=9e84e94a22c26b4f4a24879c7f3caaf5"
url= "https://www.xing.com/jobs/search?id=9e84e94a22c26b4f4a24879c7f3caaf5&keywords=Mathematiker&sc_o=jobs_search_button"
url = "https://www.xing.com/jobs/search?id=4f5a8d3f8a2f75e3357e45a0caf679b8&keywords=Mathematiker&sc_o=jobs_search_button&employmentType=INTERN.dc571c"
html = requests.get(url).text

# %%
def update_job(existing_jobs, new_job):
    job_found = False
    for job in existing_jobs:
        # Wenn der Job bereits existiert (z.B. gleicher Titel und Firma)
        if job["job_title"] == new_job["job_title"] and job["company_name"] == new_job["company_name"]:
            # Job existiert, aktualisiere die Felder, wenn sie unterschiedlich sind
#             for key, value in new_job.items():
#                 if job[key] != value:
#                     print(f"Updating '{key}': '{job[key]}' -> '{value}'")
#                     job[key] = value
#             job_found = True
            print("Job existiert bereits")
            break
    
    # Wenn der Job noch nicht existiert, füge ihn zur Liste hinzu
    if not job_found:
        print("Neuer Job hinzugefügt")
        existing_jobs.append(new_job)
        job_counter =+ 1

# %%
from bs4 import BeautifulSoup
import json

def pv(values):
    for v in values: 
        a = v.get_text(strip=True)
        print(a)
        print(":::")
        
def extract_from_xing(html: str) -> str:
    # Parse the HTML
    soup = BeautifulSoup(html, 'html.parser')

    # Find all relevant job cards
    job_cards = soup.find_all('a', class_='job-teaser-list-item-styles__ListItem-sc-6f56f6e7-1 jOANXi')
    #job_cards = soup.find_all('li', class_='result__Item-sc-5a2ae6ae-0 zlCKj')
    #job_cards = soup.find_all('article', class_='result__Item-sc-5a2ae6ae-0 zlCKj')

    if not job_cards:
        return json.dumps({"error": "No job cards found"}, indent=4, ensure_ascii=False)

    all_job_details = [{
        "job_title": "Trainee im Bereich IT (m/w/d)",
        "company_name": "Holistic42 GmbH",
        "location": "Ludwigsburg",
        "job_type": "FÃ¼r Studenten",
        "money": "FÃ¼r Studenten",
        "posted_date": "Mitarbeiterangeboten Unsere Empfehlungsprogramm \"Mitarbeiter-werben-Mitarbeiter\" So sieht dein Weg vom Junior zum Experten aus: Egal ob Entwickler, Consultant,Mathematiker",
        "Zu den ersten gehören": " "
    },
    {
        "job_title": "Data Science - Studentische Hilfskraft / Praktikant/-in (m/w/d)",
        "company_name": "logarithmo GmbH & Co. KG",
        "location": "Dortmund",
        "job_type": "FÃ¼r Studenten",
        "money": "FÃ¼r Studenten",
        "posted_date": "In unseren interdisziplinÃ¤ren Teams ergÃ¤nzen sich Softwareentwickler,Mathematiker, Ingenieure und Designer.",
        "Zu den ersten gehören": " "
    }]
    
    job_counter= 0
    
    for job_card in job_cards:
        try:
            # Extract job details
            #print("MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM")
            job_title = job_card.find('h3').get_text(strip=True)
            
            p_values = job_card.find_all('p')#.get_text(strip=True)
            company_name = p_values[1].get_text(strip=True)
            location = p_values[0].get_text(strip=True) 
            posted_date = p_values[2].get_text(strip=True)
            #pv(p_values)
            
            span_values = job_card.find_all('span', class_="body-copy-styles__BodyCopy-sc-846cf07c-0 kXwjjV marker-styles__Text-sc-7db6e05c-2 eEsTwm")
            job_type = span_values[-1].get_text(strip=True)
            money = span_values[-1].get_text(strip=True)
            if len(span_values) > 2:
                dieersten = span_values[0].get_text(strip=True)
            else: 
                dieersten = " "
            #pv(span_values) 
            
            #span = job_card.find_all('span')
            #pv(span)
          
            
#             for s in span:
#         # Überprüfen, ob der span eine Klasse hat
#                 if span.get('class'):  # Wenn die Klasse vorhanden ist
#                     print(s.get_text(strip=True))
#                 else:  # Wenn die Klasse nicht vorhanden ist
#                     print(s.get_text(strip=True), "ohne classe ")
            
            
            
            # Extract job description points
            job_description_items = job_card.find_all('li')
            job_description = [item.get_text(strip=True) for item in job_description_items]

            # Structure the extracted data
            job_details = {
                "job_title": job_title,
                "company_name": company_name,
                "location": location,
                "job_type": job_type,
                "money" : money,
                "posted_date": posted_date,
                "Zu den ersten gehören": dieersten
                #"job_description": job_description
            }
            
            update_job(all_job_details, job_details)
                    
            
            #all_job_details.append(job_details)
            #job_counter=+ 1 
            

        except AttributeError:
            # Handle cases where a job card is incomplete
            all_job_details.append({"error": "Failed to parse some job details for this card"})

    # Convert all job details to JSON
    print("Job Counter: ", job_counter)
    print("All Job Deatails: ", len(all_job_details))
    return json.dumps(all_job_details, indent=4, ensure_ascii=False)

result = extract_from_xing(html)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 109
#     106     print("All Job Deatails: ", len(all_job_details))
#     107     return json.dumps(all_job_details, indent=4, ensure_ascii=False)
# --> 109 result = extract_from_xing(html)
#     110 print(result)
#
# NameError: name 'html' is not defined

# %%
soup = BeautifulSoup(html, 'html.parser')
job_cards = soup.find_all('article', class_='result__Item-sc-5a2ae6ae-0 zlCKj')

job_cards = soup.find_all('a', class_='job-teaser-list-item-styles__ListItem-sc-6f56f6e7-1 jOANXi')
#a data-testid="job-search-result" class="job-teaser-list-item-styles__ListItem-sc-6f56f6e7-1 jOANXi"
print(job_cards)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 soup = BeautifulSoup(html, 'html.parser')
#       2 job_cards = soup.find_all('article', class_='result__Item-sc-5a2ae6ae-0 zlCKj')
#       4 job_cards = soup.find_all('a', class_='job-teaser-list-item-styles__ListItem-sc-6f56f6e7-1 jOANXi')
#
# NameError: name 'html' is not defined

# %% [markdown]
# # Selenium

# %%
from selenium import webdriver

# Pfad zum ChromeDriver (stelle sicher, dass du den korrekten Pfad verwendest)
driver = webdriver.Chrome(executable_path =r'C:\Users\User\.wdm\drivers\chromedriver\win64\129.0.6668.100\chromedriver-win32\chromedriver.exe')
driver.get("https://nextstephr.de/")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 from selenium import webdriver
#       3 # Pfad zum ChromeDriver (stelle sicher, dass du den korrekten Pfad verwendest)
# ----> 4 driver = webdriver.Chrome(executable_path =r'C:\Users\User\.wdm\drivers\chromedriver\win64\129.0.6668.100\chromedriver-win32\chromedriver.exe')
#       5 driver.get("https://nextstephr.de/")
#
# TypeError: WebDriver.__init__() got an unexpected keyword argument 'executable_path'

# %%
which chromedriver
# Out:
#   Cell In[5], line 1
#     which chromedriver
#           ^
# SyntaxError: invalid syntax

# %%
from webdriver_manager.chrome import ChromeDriverManager

# Hole den Pfad zum ChromeDriver
chromedriver_path = ChromeDriverManager().install()

# Ausgabe des Pfads
print(f'ChromeDriver ist installiert unter: {chromedriver_path}')
# Out:
# ChromeDriver ist installiert unter: C:\Users\User\.wdm\drivers\chromedriver\win64\129.0.6668.100\chromedriver-win32/chromedriver.exe

# %%
chrome_driver_path = r'C:\Users\User\.wdm\drivers\chromedriver\win64\129.0.6668.100\chromedriver.exe'
url  = "https://nextstephr.de/"
url = "https://de.indeed.com/jobs?q=Mathematiker&l=&from=searchOnHP&vjk=4502c46a336fc4de"

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Pfad zum ChromeDriver (aktualisiere den Pfad)

# Verwende die neue Service-Klasse
service = Service(executable_path=chrome_driver_path)

# Initialisiere den WebDriver mit dem Service-Objekt
driver = webdriver.Chrome(service=service)

# Öffne eine Webseite
driver.get(url)
print(f"Der Titel der Webseite ist: {driver.title}")
# Out:
# Der Titel der Webseite ist: Mathematiker: > 2.000 Jobs, Arbeit, 16. Oktober 2024| Indeed.com

# %%
button_code = """<button data-xds="Button" class="button-styles__Button-sc-9c115803-1 bIQunG"><div class="button-styles__InnerContent-sc-9c115803-3 fOcggO"><span class="button-styles__Text-sc-9c115803-5 kDIpGV">Show more</span></div></button>"""

# %%
import re
number_text = "15.3Jobs"
def get_number(number_text):# Nur die Ziffern extrahieren
    number_text = number_text.replace('.', '')
    digits = re.findall(r'\d+', number_text)[0]
    number_int = int(digits)  # Den Text in einen Integer umwandeln
    return number_int

a = get_number(number_text)
print(a)  # Ausgabe: 153
# Out:
# 153

# %%
def scroll_until_job_count(url, job_count_target): 
    # Öffne die Webseite
    driver.get(url)
    time.sleep(2)

    # Initiale Höhe der Seite abrufen
    last_height = driver.execute_script("return document.body.scrollHeight")
    total_jobs_found = 0  # Variable, um die Anzahl der gefundenen Jobs zu verfolgen

    while total_jobs_found < job_count_target:
        # Scrolle bis zum Ende der Seite
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Warte, damit die Seite genug Zeit hat, neue Inhalte zu laden
        time.sleep(2)  # Diese Wartezeit kann je nach Ladegeschwindigkeit der Webseite angepasst werden

        # Finde die Job-Elemente auf der Seite
        jobs = soup.find_all('a', class_='job-teaser-list-item-styles__ListItem-sc-6f56f6e7-1 jOANXi')
        #jobs = driver.find_elements_by_class_name('job-teaser-list-item-styles__ListItem-sc-6f56f6e7-1')  # Hier anpassen an das HTML der Webseite
        total_jobs_found = len(jobs)  # Anzahl der gefundenen Jobs
        
        #print(f"Gefundene Jobs: {total_jobs_found}")
        
        # Hole die neue Höhe der Seite
        new_height = driver.execute_script("return document.body.scrollHeight")

        # Überprüfe, ob neue Inhalte geladen wurden (d.h. ob die Höhe sich geändert hat)
        if new_height == last_height:
            print("Ende des Inhalts erreicht.")
            break  # Breche die Schleife ab, wenn die Seitenhöhe sich nicht mehr ändert

        # Aktualisiere die letzte bekannte Höhe der Seite
        last_height = new_height

    # Optional: Warte ein wenig, um zu sehen, dass der Vorgang beendet ist
    time.sleep(3)
    html_content = driver.page_source
    return html_content

# %%
def scroll(url): 
    #driver.get(url)
    time.sleep(2)

# Initiale Höhe der Seite abrufen
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scrolle bis zum Ende der Seite
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Warte, damit die Seite genug Zeit hat, neue Inhalte zu laden
        time.sleep(2)  # Diese Wartezeit kann je nach Ladegeschwindigkeit der Webseite angepasst werden

        # Hole die neue Höhe der Seite
        new_height = driver.execute_script("return document.body.scrollHeight")

        # Überprüfe, ob neue Inhalte geladen wurden (d.h. ob die Höhe sich geändert hat)
        if new_height == last_height:
            print("Ende des Inhalts erreicht.")
            break  # Breche die Schleife ab, wenn die Seitenhöhe sich nicht mehr ändert

        # Aktualisiere die letzte bekannte Höhe der Seite
        last_height = new_height

    # Optional: Warte ein wenig, um zu sehen, dass der Vorgang beendet ist
    time.sleep(3)
    html_content = driver.page_source
    return html_content

def find_anzahl_jobs(url):
    driver.get(url)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import time

# siehe https://github.com/mozilla/geckodriver/releases/tag/v0.35.0
geckodriver_path=chrome_driver_path

# start
service = Service(geckodriver_path)
driver = webdriver.Chrome(service=service)

# seite öffnen
url = 'https://www.xing.com/jobs/search?id=9e84e94a22c26b4f4a24879c7f3caaf5&keywords=Mathematiker&sc_o=jobs_search_button'

#url = 'https://www.xing.com/jobs/search?id=5801ee5720da177ec50526704b0e7fbf&keywords=Mathe&sc_o=jobs_search_button'
#url = 'https://de.indeed.com/jobs?q=Mathematiker&l=&from=searchOnHP&vjk=4502c46a336fc4de'
#driver.get('https://www.xing.com/jobs/search?sc_o=losp_jobs_search_button_click&sc_o_PropActionOrigin=losp_job_search&keywords=physik&id=d0956e91aafb350005f20aa2e9ef6014')

driver.get(url)
html_content = driver.page_source
soup = BeautifulSoup(html_content, 'html.parser')
headline = soup.find('h1', class_='headline-styles__Headline-sc-df17ff0a-0')
if headline:
    number_text = headline.get_text(strip=True).split()[0]  # Nur die Zahl extrahieren
    number_text = get_number(number_text)
    print("Anzahl Jobs: ", number_text)

#html = scroll(url, )
html = scroll_until_job_count(url, number_text)

resultate = extract_from_xing(html)
#print(result)

# Locate the button and click it
try:
    # You may need to adjust the locator method (By.ID, By.XPATH, By.CLASS_NAME, etc.)
    button = driver.find_element(By.CLASS_NAME, 'button-styles__Button-sc-9c115803-1')  # Replace 'button-id' with the actual button identifier
    #button = driver.find_element(By.XPATH, "//button[.//span[text()='Show more']]")
    #button = driver.find_element_by_class_name('button-styles__Button-sc-9c115803-1 bIQunG')
    button.click()
except Exception as e:
    print(f"Error: {e}")

# Optional: Add a wait or other actions here if needed



#get.htlm 
#drive.source 


# Close the browser once done
driver.quit()
# Out:
# Anzahl Jobs:  155
# Ende des Inhalts erreicht.
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job_doppelt
# Job Counter:  0
# All Job Deatails:  0
# Error: Message: element not interactable
#   (Session info: chrome=129.0.6668.101)
# Stacktrace:
# 	GetHandleVerifier [0x00265523+24195]
# 	(No symbol) [0x001FAA04]
# 	(No symbol) [0x000F1F09]
# 	(No symbol) [0x00137EDF]
# 	(No symbol) [0x0012D4FD]
# 	(No symbol) [0x0015AB3C]
# 	(No symbol) [0x0012CFB4]
# 	(No symbol) [0x0015ADD4]
# 	(No symbol) [0x00175280]
# 	(No symbol) [0x0015A8D6]
# 	(No symbol) [0x0012BA27]
# 	(No symbol) [0x0012C43D]
# 	GetHandleVerifier [0x0052CE13+2938739]
# 	GetHandleVerifier [0x0057EC69+3274185]
# 	GetHandleVerifier [0x002F09C2+594722]
# 	GetHandleVerifier [0x002F7EDC+624700]
# 	(No symbol) [0x002037CD]
# 	(No symbol) [0x00200528]
# 	(No symbol) [0x002006C5]
# 	(No symbol) [0x001F2CA6]
# 	BaseThreadInitThunk [0x7589FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7793809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7793806E+238]
# 	(No symbol) [0x00000000]

# %% [markdown]
# Math: 1000/19159
# scrolen mit suchanzahl vergleichen

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %% [markdown]
# heute: Datenbank,ohne duplication
# vllt. korelation mit mathlab , verteilungsplot

# %% [markdown]
# # Datenbank

# %%
import sqlite3

def show_table(name_of_table): 
# Verbindung zur Datenbank herstellen
    conn = sqlite3.connect('mydatabase.db')

# Cursor-Objekt erzeugen
    cursor = conn.cursor()

# Tabellenname, den du abrufen möchtest (zum Beispiel 'person_data')
    #table_name = 'person_data'
    table_name = name_of_table

# Dynamische SQL-Abfrage, um alle Daten der Tabelle zu holen
    cursor.execute(f'SELECT * FROM {table_name}')

# Alle Zeilen der Tabelle abrufen
    rows = cursor.fetchall()

# Überschriften der Spalten herausfinden (optional, falls benötigt)
    cursor.execute(f'PRAGMA table_info({table_name})')
    columns = [column[1] for column in cursor.fetchall()]

# Überschriften ausgeben
    print(" | ".join(columns))

# Jede Zeile der Tabelle ausgeben
    for row in rows:
        print(" | ".join(map(str, row)))
    
# Verbindung schließen
    conn.close()

show_table("job_data")
# Out:
# id | job_title | company_name | location | money
# 1 | (Wirtschafts-)Mathematiker (m/w/d) für den Bereich Aktuariat (Kranken) | Concordia Versicherungen | Hannover | 61.000 €–89.500 €
# 2 | Mathematiker (m/w/d) im Versicherungsbereich - 30 Std/Woche | Lehmann Personalmanagement GmbH | Stuttgart | 50.500 €–67.000 €
# 3 | Mathematiker (m/w/d) im Risk Management mit Schwerpunkt Risikosysteme | Swiss Life Lebensversicherung SE | Garching bei München | 54.500 €–70.500 €
# 4 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Essen | 70.000 €–90.000 €
# 5 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Mannheim | 70.000 €–90.000 €
# 6 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Hamburg | 70.000 €–90.000 €
# 7 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Leipzig | 70.000 €–90.000 €
# 8 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Köln | 70.000 €–90.000 €
# 9 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Dresden | 70.000 €–90.000 €
# 10 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Dortmund | 70.000 €–90.000 €
# 11 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Bremen | 70.000 €–90.000 €
# 12 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | München | 70.000 €–90.000 €
# 13 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Berlin | 70.000 €–90.000 €
# 14 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Limburg an der Lahn | 70.000 €–90.000 €
# 15 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Düsseldorf | 70.000 €–90.000 €
# 16 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Frankfurt am Main | 70.000 €–90.000 €
# 17 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Nürnberg | 70.000 €–90.000 €
# 18 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Stuttgart | 70.000 €–90.000 €
# 19 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Hannover | 70.000 €–90.000 €
# 20 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Duisburg | 70.000 €–90.000 €
# 21 | Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd) | Vesterling AG | Hannover | 70.000 € – 90.000 €
# 22 | Mathematiker / Aktuar (m/w/d) Aktuarielle Bewertung | DEVK | Köln | 43.500 € – 78.500 €
# 23 | Junior Mathematiker:in (Versicherung / Produktmathematik) | Viridium Customer Services GmbH | Hamburg | Vollzeit
# 24 | (Junior) Mathematiker (m/w/d) Spieleentwicklung | univativ GmbH | Lübbecke | 42.000 € – 52.000 €
# 25 | Versicherungs- / Wirtschafts-Mathematiker (m/w/d) | Recruiter Netzwerk | Stuttgart | 81.000 € – 92.000 €
# 26 | Mathematiker:in Rückversicherung | Sparkassen-Finanzgruppe | Stuttgart | 56.500 € – 75.500 €
# 27 | Diplom-Informatiker/ Medizin- (Bio-)Informatiker / Mathematiker (Univ./FH)  (Elternzeitvert (m/w/d) | Klinikum der Universität München | München | 54.500 € – 82.000 €
# 28 | Mathematiker/-in Pensionsversicherungsmathematik in der bAV (all genders) | adesso benefit solutions GmbH | Bensheim | 52.000 € – 72.500 €
# 29 | Mathematiker/ Physiker für die Revision in einer internationalen Bank (gn) | PS Direkt GmbH & Co. KG Private Arbeitsvermittlung | Köln | 54.500 € – 80.500 €
# 30 | Mathematiker als Softwareentwickler (m/w/d) in der Krankenversicherung | Continentale Versicherungsverbund | Dortmund | 53.500 € – 75.000 €
# 31 | Mathematiker (m/w/d) im Versicherungswesen | DIS AG | Hamburg | 51.500 € – 68.000 €
# 32 | Wirtschaftsinformatiker/-in oder Mathematiker/-in im Rechnungswesen | Commerzbank AG | Halle (Saale) | 53.000 € – 76.000 €
# 33 | Mathematiker (m/w/d) in der Lebensversicherung | Continentale Versicherungsverbund | München | 57.500 € – 76.500 €
# 34 | Junior Mathematiker:in (Direkteinstieg in die Interne Revision) | Viridium Group Services GmbH | Neu-Isenburg | Vollzeit
# 35 | Mathematiker Softwareentwicklung (m/w/d) | Brunel GmbH NL Karlsruhe | Freiburg im Breisgau | 50.000 € – 70.500 €
# 36 | (Wirtschafts-)Mathematiker/Physiker/Informatiker für Schnittstellenentwicklung im E-Commerce (m/w/d) | RSU GmbH | Ulm | 49.500 € – 55.500 €
# 37 | Physiker/Mathematiker für Messtechnikentwicklung (m/w/d) | Brunel GmbH NL Ulm | Ulm | 54.500 € – 74.000 €
# 38 | Mathematiker Softwareentwicklung (m/w/d) | Brunel | Freiburg im Breisgau | Vollzeit
# 39 | Physiker/Mathematiker für Messtechnikentwicklung (m/w/d) | Brunel | Ulm | Vollzeit
# 40 | Physiker oder Mathematiker (m/w/d) als Systemingenieur | FERCHAU GmbH | Ulm | 65.000 € – 75.000 €
# 41 | Mathematiker:in / Aktuar:in (Quantitatives Risikomanagement / Versicherung) | Viridium Group Services GmbH | Leverkusen | Vollzeit
# 42 | Junior Mathematiker:in (Versicherung / Produktmathematik) | Viridium Gruppe | Neu-Isenburg | Vollzeit
# 43 | Mathematiker:in / Aktuar:in (Quantitatives Risikomanagement / Versicherung) | Viridium Group Services GmbH | Neu-Isenburg | Vollzeit
# 44 | Mathematiker (m/w/d) Pensionsfonds | DEVK | Köln | 46.500 € – 62.500 €
# 45 | Mathematiker (m/w/d) Statistik und Datenanalyse in Mannheim (915) | BRÜGGEN ENGINEERING GmbH | Mannheim | 50.500 € – 70.500 €
# 46 | Mathematiker (m/w/d) | Randstad Deutschland GmbH & Co. KG | Mannheim | Vollzeit
# 47 | Mathematiker (m/w/d) Betriebliche Altersversorgung | DEVK | Köln | 46.500 € – 62.500 €
# 48 | (Business) Mathematician / Physicist Life and Health Reinsurance | Hannover Rück SE | Hannover | 58.000 € – 67.500 €
# 49 | Mathematiker (m/w/d) für die fachliche Anwendungsentwicklung | Generali Deutschland AG | Aachen | 71.000 € – 84.500 €
# 50 | Mathematiker (m/w/d) für die Bestandsverwaltungssysteme der Lebensversicherung | Generali Deutschland AG | Aachen | 70.000 € – 81.500 €
# 51 | Mathematiker im Aktuariat Finanzen (m/w/d) | Allianz Deutschland | München | 55.500 € – 80.000 €
# 52 | IT-Affiner Physiker (m/w/d), Mathematiker (m/w/d) oder Ingenieur (m/w/d) für Bildverarbeitende Systeme | Diehl Defence | Röthenbach an der Pegnitz | 48.500 € – 80.500 €
# 53 | Informatiker/Mathematiker (m/w/d) - objektorientierte Softwareentwicklung in der Krankenversicherung | Württembergische Versicherung AG | Kornwestheim | 53.000 € – 82.000 €
# 54 | Mathematiker Spielentwicklung ­­/­­ Game Design Mathematician (m|w|d) | LÖWEN ENTERTAINMENT GmbH | Mainz | 49.000 € – 55.500 €
# 55 | (Wirtschafts-) Mathematiker m/w/d | SÜDVERS Holding GmbH & Co. KG | Idstein | 55.000 € – 73.500 €
# 56 | Mathematiker für den Berufseinstieg im Risikocontrolling (m/w/d) | HOLISTIC42 GmbH | Stuttgart | 48.500 € – 69.500 €
# 57 | Mathematiker, Physiker, Informatiker, Modellentwickler (m/w/d) – Kreditrisiko | S Rating und Risikosysteme GmbH | Berlin | 50.000 € – 76.000 €
# 58 | Senior Mathematician/Statistician (m/w/d) | Hays Professional Solutions GmbH Standort Mannheim | Mannheim | Vollzeit
# 59 | (Business) Mathematician Underwriting French-Speaking Markets | Hannover Rück SE | Hannover | 55.500 € – 66.500 €
# 60 | (Business-) Mathematician / Underwriter US Property | Hannover Rück SE | Hannover | 62.500 € – 84.000 €
# 61 | Mathematician / Actuary Life and Health Model Development | Hannover Rück SE | Hannover | 57.500 € – 89.000 €
# 62 | IT-Affiner Physiker (m/w/d), Mathematiker (m/w/d) oder Ingenieur (m/w/d), vorzugsweise mit Promotion | Diehl Defence GmbH & Co. KG | Überlingen | 50.000 € – 65.000 €
# 63 | IT-Affiner Physiker (m/w/d), Mathematiker (m/w/d) oder Ingenieur (m/w/d), vorzugsweise mit Promotion | Diehl Defence | Überlingen | 50.000 € – 82.500 €
# 64 | Mathematiker/Aktuar - Risikomanagement/Solvency II (d/m/w) | aktuarielle Beratungsgesellschaft | Köln | 48.500 € – 82.000 €
# 65 | Mathematiker und C#, .NET Developer (m/w/d) | KA Resources | Würzburg | 49.500 € – 67.000 €
# 66 | Mathematiker/Pricing-Aktuar (w/m/d) in Voll- oder Teilzeit | VHV Allgemeine Versicherung AG | Hannover | 69.000 € – 99.000 €
# 67 | Actuary / Mathematician / Property Casualty | Hannover Rück SE | Hannover | 57.500 € – 82.500 €
# 68 | EY-Parthenon Mathematiker - HR Transactions - Transaction Strategy & Execution (w/m/d) | EY Deutschland | Frankfurt am Main | Vollzeit
# 69 | Mathematiker / Aktuar (m/w/d) | Lebensversicherung von 1871 a. G. München | München | 82.000 € – 107.500 €
# 70 | Mathematiker (m/w/d) Aktuariat Schaden- und Unfallversicherung (Teilzeit) | Verband öffentlicher Versicherer | Düsseldorf | 53.500 € – 76.500 €
# 71 | Informatiker/Ingenieur/ Physiker/ Mathematiker (m/w/d) für die Entwicklung von Embedded Software | ITPower Solutions GmbH | Berlin | 49.000 € – 65.500 €
# 72 | Mathematiker:in für E-Learning-Plattform | Mathelöser | Köln | Selbstständig
# 73 | Mathematiker/Aktuar m/w/d | VST Gesellschaft für Versicherungsstatistik mbH | Hannover | 47.500 € – 78.500 €
# 74 | Mathematiker - Aktuar - Versicherungsmathematiker (m/w/d) für die betriebliche Altersversorgung | Lutz Pension Consulting GmbH | Bergisch Gladbach | 51.500 € – 83.000 €
# 75 | Mathematiker:in Tarifierung (w/m/d) | HUK-COBURG VVaG | Coburg | 51.500 € – 69.000 €
# 76 | Mathematiker:in / Physiker:in Aktuarielles Controlling (w/m/d) | HUK-COBURG VVaG | Coburg | 50.500 € – 66.000 €
# 77 | Senior Aktuar/ Mathematiker Rückversicherung (m/w/d) | DEVK | Köln | 47.500 € – 77.500 €
# 78 | Consultant Karrierestart/Quereinstieg als WiWi, Mathematiker, Physiker - Financial Services (w/m/d) | EY Deutschland | Frankfurt am Main | Vollzeit
# 79 | Praktikant Mathematiker, Informatiker, Physiker - prüfungsnahe Beratung/Quants (w/m/d) | EY Deutschland | Frankfurt am Main | Für Studenten
# 80 | Mathematician Underwriting | Hannover Rück SE | Hannover | 55.000 € – 66.500 €
# 81 | Economist / Mathematician / Underwriter Italy | Hannover Rück SE | Hannover | 58.500 € – 84.500 €
# 82 | Mathematiker Softwareentwicklung (m/w/d) | Guldberg GmbH | Gilching | 50.000 € – 64.000 €
# 83 | Mathematiker (m/w/d) im quantitativen Risikomanagement | Deutsche Bausparkasse Badenia AG | Karlsruhe | 57.500 € – 84.000 €
# 84 | Mathematiker (w/m/d) Kompositversicherung | Barmenia Versicherungen | Wuppertal | 51.000 € – 64.500 €
# 85 | Mathematiker / Physiker als Softwareentwickler Quantitative Methoden (w|m|d) | zeb.rolfes.schierenbeck.associates gmbh | Berlin | 43.000 € – 63.500 €
# 86 | Physiker (m/w/d), Mathematiker (m/w/d) oder Ingenieur (m/w/d), vorzugsweise mit Promotion, für Algorithmen und Verfahren und deren Bewertung | Diehl Defence | Überlingen | 50.500 € – 79.500 €
# 87 | Aktuar / Mathematiker (m/w/d) im Bereich Komposit-Versicherung | Württembergische Versicherung AG | Kornwestheim | 58.000 € – 89.000 €
# 88 | Mathematiker / Physiker (m/w/d) | R+V Versicherung | Wiesbaden | 58.500 € – 83.000 €
# 89 | Mathematiker / Physiker / Chemiker als IT Berater (w/m/d) | Best Practice Consulting AG | Hamburg | 47.000 € – 64.000 €
# 90 | Mathematiker (m/w/d) Tarifentwicklung Leben | VOLKSWOHL BUND Versicherungen | Dortmund | 54.500 € – 69.000 €
# 91 | Mathematiker / Physiker / Chemiker als IT Berater (w/m/d) | Best Practice Consulting AG | Münster | 46.500 € – 64.000 €
# 92 | Mathematiker / Naturwissenschaftler als Analyst (w/m/d) | Allianz Deutschland | Stuttgart | 53.000 € – 80.000 €
# 93 | Junior Mathematiker:in (Versicherung / Solvency II) | Viridium Holding AG | Leverkusen | Vollzeit
# 94 | C++ Softwareentwickler ereignisorientierte Simulationen (m/w/d) | DR. HARTMUTH & PARTNER | München | 80.000 € – 120.000 €
# 95 | Junior Aktuar / Junior Consultant (m/w/d) | WTW | Köln | Vollzeit
# 96 | Softwareentwickler (m/w/d) Triebswerks- und Komponentenerprobung | PASIT Professionelle Personallösungen GmbH | München | 48.000 € – 61.500 €
# 97 | C++ Softwareentwickler ereignisorientierte Simulationen (m/w/d) | DR. HARTMUTH & PARTNER | München | 80.000 € – 120.000 €
# 98 | Java - Softwareentwickler verteilte Simulationen (m/w/d) | DR. HARTMUTH & PARTNER | München | 80.000 € – 120.000 €
# 99 | Softwareentwickler (m/w/d) Triebswerks- und Komponentenerprobung | EMMA JOBS in München | München | 49.000 € – 67.000 €
# 100 | Risikomanager (Mensch*) Schwerpunkt IKT | Deutsche Rückversicherung AG | Düsseldorf | 56.000 € – 90.500 €
# 101 | Dr. rer. nat. Physik / Chemie - Vorentwicklung & Projektmanagement (m/w/d) | Professional Scientists GmbH & Co. KG | Stuttgart | 51.500 € – 77.000 €
# 102 | Entwicklungsingenieur Antennentechnik Flugzeug (w/m/d) | AGILIOS Personal GmbH | Manching | 54.500 € – 66.500 €
# 103 | Referent (Mensch*) Spartenmanagement HUK | Deutsche Rückversicherung AG | Düsseldorf | 54.500 € – 83.000 €
# 104 | Consultant Market Research & Data Analytics (m/w/d) | Instaffo GmbH | Paderborn | 50.000 € – 70.000 €
# 105 | Softwaretester (m/w/d) | Brunel GmbH NL Erfurt | Erfurt | 43.000 € – 61.000 €
# 106 | Fachrevisor (m/w/d) | Berlin Hyp AG | Berlin | 61.000 € – 81.000 €
# 107 | Markt- und Institutsaufseher*innen (w/m/d) für die Wertpapieraufsicht / Asset-Management | Bundesanstalt für Finanzdienstleistungsaufsicht (BaFin) | Frankfurt am Main | 49.000 € – 72.000 €
# 108 | Softwaretester (m/w/d) | Brunel | Erfurt | Vollzeit
# 109 | Postdoc in Machine Learning & Non-invasive Tumor Profiling | Deutsches Krebsforschungszentrum (DKFZ) | Heidelberg | Vollzeit
# 110 | Teamleitung (m/w/d) Controlling & Planung | UmweltBank AG | Nürnberg | 68.500 € – 99.500 €
# 111 | Mathematiker, Statistiker, Aktuar (DAV) im Produktaktuariat (m/w/d) | Allianz Deutschland | München | 58.000 € – 92.000 €
# 112 | (Senior-) Software Developer Prognose & KI (m/w/d) | Robotron Datenbank-Software GmbH | Leipzig | 40.000 € – 61.000 €
# 113 | Mathematiker / Aktuar Lebensversicherung (m/w/d) | ERGO Group AG | Hamburg | 75.500 € – 104.000 €
# 114 | Senior Pharmacometrician (all genders) (12 months temporary / full- or part-time) | AbbVie Deutschland GmbH & Co. KG | Ludwigshafen am Rhein | 51.500 € – 77.500 €
# 115 | Studiengang Applied Mathematics, B.Sc. (m/w/d) an der Hochschule Mittweida | Hochschule Mittweida | Mittweida | Für Studenten
# 116 | Studiengang Applied Mathematics for Network and Data Sciences, M.Sc. (m/w/d) an der Hochschule Mittweida | Hochschule Mittweida | Mittweida | Für Studenten
# 117 | Lerntherapeut/in für Rechenschwäche am Standort Eberswalde gesucht | Duden Institut für Lerntherapie Eberswalde | Eberswalde | 46.500 € – 65.500 €
# 118 | Promotionsstelle in der Physikalischen Ozeanographie und Messtechnik | Leibniz-Institut für Ostseeforschung Warnemünde | Rostock | 47.000 € – 51.500 €
# 119 | Dr. rer. nat. Physik / Chemie – Vorentwicklung & Projektmanagement (m/w/d) | Professional Scientists GmbH & Co. KG | Stuttgart | 53.000 € – 83.000 €
# 120 | Masterarbeit / Abschlussarbeit mit Fokus auf Operations Research (all genders) | INFORM Institut für Operations Research und Management GmbH | Aachen | Für Studenten
# 121 | IT Support Mitarbeiter - Kundenbetreuung (all genders) | INFORM Institut für Operations Research und Management GmbH | Aachen | 35.500 € – 55.500 €
# 122 | Senior Fullstack Developer (all genders) – im KI Bereich | INFORM Institut für Operations Research und Management GmbH | Aachen | 49.500 € – 76.500 €
# 123 | IT Projektmanager (all genders) - Workforce Management | INFORM Institut für Operations Research und Management GmbH | Aachen | 45.500 € – 72.500 €
# 124 | Embedded System Engineer (w/m/d) | Brunel GmbH NL Hannover | Hannover | 49.500 € – 72.500 €
# 125 | Embedded System Engineer (w/m/d) | Brunel | Hannover | Vollzeit
# 126 | Trainee im Bereich IT (m/w/d) | Holistic42 GmbH | Ludwigsburg | Für Studenten
# 127 | Ingenieur (m/w/d) Physikalische Berechnungen | FERCHAU GmbH | Essen | 55.000 € – 70.000 €
# 128 | (Wirtschafts-)Mathematiker/Statistiker (m/w/d) | hkp/// group | Frankfurt am Main | Vollzeit
# 129 | Data Science - Studentische Hilfskraft / Praktikant/-in (m/w/d) | logarithmo GmbH & Co. KG | Dortmund | Für Studenten
# 130 | Data Science Consultant (m/w/d) | Sopra Steria Consulting | Deutschland | 57.500 € – 83.000 €
# 131 | (Senior-) Software Developer Prognose & KI | Robotron Schweiz GmbH | Dresden | Vollzeit
# 132 | Datascientist*in oder Mathematiker*in (m/w/d) [German speaker only] | Cavorit Consulting GmbH | Forst (Lausitz) | Vollzeit
# 133 | Fachbereich Mathematik und Informatik - Institut für Mathematik AG Diskrete Geometrie & Topologische Kombinatorik | Freie Universität Berlin | Berlin | Vollzeit
# 134 | Java Entwickler (w/m/d) | Axians Athos GmbH | Sindelfingen | 48.000 € – 75.500 €
# 135 | Mathematiker (m/w/d) im Risk Management mit Schwerpunkt Risikosysteme | Swiss Life Holding | Garching bei München | 56.500 € – 65.500 €
# 136 | Junior Consultant Data Science Telecommunication & Media (m/w/d) | Sopra Steria Consulting | Deutschland | Vollzeit
# 137 | Java - Softwareentwickler verteilte Simulationen (m/w/d) | IABG | Ottobrunn bei München | 51.500 € – 73.500 €
# 138 | C++ Softwareentwickler ereignisorientierte Simulationen (m/w/d) | IABG | Ottobrunn bei München | 53.500 € – 77.000 €
# 139 | Data Scientist Datenmanagement | aktuarielle Beratungsgesellschaft | Köln | 48.500 € – 74.500 €
# 140 | Aktuarieller Consultant Lebensversicherung (w/m/d) | HBA-Consulting AG | Idstein | 52.500 € – 77.500 €
# 141 | Senior Fullstack Java/Angular Developer (M/E/N/S/C/H) | WhizUs GmbH | Wien | 60.000 € – 85.000 €
# 142 | Cloud Native Engineer (M/E/N/S/C/H) | WhizUs GmbH | Wien | 60.000 € – 90.000 €
# 143 | Business Analyst Personenversicherung Rechenkern (m/w/d) | R+V Versicherung | Wiesbaden | 58.000 € – 91.000 €
# 144 | Werkstudent (Wirtschafts-) Mathematik / Physik / Informatik (m/w/d) | R+V Versicherung | Wiesbaden | Für Studenten
# 145 | Testmanager (w/m/d) | Barmenia Versicherungen | Wuppertal | 52.500 € – 77.000 €
# 146 | Machine Learning Entwickler:in | alfatraining Bildungszentrum GmbH | Hannover | Selbstständig
# 147 | Machine Learning Entwickler:in | alfatraining Bildungszentrum GmbH | Rostock | Selbstständig
# 148 | Projektleiter:in im SAP-Umfeld | GAB-Solution GmbH | Berlin | 61.000 € – 99.500 €
# 149 | Revisor (m/w/d) mit Schwerpunkt IT | Cobalt Deutschland GmbH | Berlin | 46.000 € – 74.500 €
# 150 | Software Entwickler*In (w/m/d) | Stiefsohn Consulting GmbH | Österreich | Vollzeit

# %%
import sqlite3
import json

# Verbindung zur Datenbank herstellen (oder eine neue erstellen)
conn = sqlite3.connect('mydatabase.db')

# Cursor-Objekt erzeugen
cursor = conn.cursor()

# Tabelle erstellen, falls sie noch nicht existiert
cursor.execute('''
    CREATE TABLE IF NOT EXISTS job_data (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        job_title TEXT,
        company_name TEXT,
        location TEXT,
        money TEXT
    )
''')

# Änderungen speichern
conn.commit()

# %%
conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor() 

data = json.loads(resultate)

for info in data:
    cursor.execute('''
        INSERT INTO job_data (job_title, company_name, location, money)
        VALUES (?, ?, ? ,?)
    ''', (info['job_title'], info['company_name'],info['location'],info['money'],))

# Änderungen speichern
conn.commit()


# JSON-String aus der Datenbank abrufen
cursor.execute('SELECT * FROM job_data WHERE id = 1')  # Annahme: id = 1
result_one = cursor.fetchone()

cursor.execute('SELECT id, job_title, company_name, location, money FROM job_data')# Personen-Daten mit ID abrufen
result = cursor.fetchall()# Alle Datensätze abrufen

# Wenn Daten gefunden wurden
if result_one:
    print(f"ID: {result_one[0]}, Job_name: {result_one[1]}, Company: {result_one[2]}")
else:
    print("Keine Daten mit ID = 1 gefunden.")


# Daten anzeigen
for info in result:
    a=0
    #print(f"ID: {info[0]}, Job_Name: {info[1]}, Company: {info[2]}, Ort: {info[3]}, Gehalt: {info[4]}  ")


conn.close()
# Out:
# ID: 1, Job_name: (Wirtschafts-)Mathematiker (m/w/d) für den Bereich Aktuariat (Kranken), Company: Concordia Versicherungen

# %%
print(resultate)
# Out:
# [
#     {
#         "job_title": "(Wirtschafts-)Mathematiker (m/w/d) für den Bereich Aktuariat (Kranken)",
#         "company_name": "Concordia Versicherungen",
#         "location": "Hannover",
#         "job_type": "61.000 €–89.500 €",
#         "money": "61.000 €–89.500 €",
#         "posted_date": "Verstärken Sie unser Aktuariat als (Wirtschafts-)Mathematiker(m/w/d) .",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Mathematiker (m/w/d) im Versicherungsbereich - 30 Std/Woche",
#         "company_name": "Lehmann Personalmanagement GmbH",
#         "location": "Stuttgart",
#         "job_type": "50.500 €–67.000 €",
#         "money": "50.500 €–67.000 €",
#         "posted_date": "Vor 2 Tagen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Mathematiker (m/w/d) im Risk Management mit Schwerpunkt Risikosysteme",
#         "company_name": "Swiss Life Lebensversicherung SE",
#         "location": "Garching bei München",
#         "job_type": "54.500 €–70.500 €",
#         "money": "54.500 €–70.500 €",
#         "posted_date": "AlsMathematiker(m/w/d) mit dem Schwerpunkt Risikosysteme übernimmst du vielseitige aktuarielle Aufgaben in unserem Entwicklungsteam.",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Essen",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Essen (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Mannheim",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Mannheim (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Hamburg",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Hamburg (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Leipzig",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Leipzig (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Köln",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Köln (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Dresden",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Dresden (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Dortmund",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Dortmund (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Bremen",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Bremen (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "München",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: München (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Berlin",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Berlin (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Limburg an der Lahn",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Limburg an der Lahn Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen Sie",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Düsseldorf",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Düsseldorf (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Frankfurt am Main",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Frankfurt am Main (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Nürnberg",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Nürnberg (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Stuttgart",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Stuttgart (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Hannover",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Hannover (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Duisburg",
#         "job_type": "70.000 €–90.000 €",
#         "money": "70.000 €–90.000 €",
#         "posted_date": "Standort: Duisburg (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Aktuar / Mathematiker Lebensversicherung | Fachkonzeptionen, Softwarelösungen | bis 90.000 € (mwd)",
#         "company_name": "Vesterling AG",
#         "location": "Hannover",
#         "job_type": "70.000 € – 90.000 €",
#         "money": "70.000 € – 90.000 €",
#         "posted_date": "Standort: Hannover (100% Homeoffice) Vertragsart: Unbefristete Festanstellung durch unseren Klienten Aufgaben Als Aktuar /MathematikerLebensversicherung übernehmen",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Mathematiker / Aktuar (m/w/d) Aktuarielle Bewertung",
#         "company_name": "DEVK",
#         "location": "Köln",
#         "job_type": "43.500 € – 78.500 €",
#         "money": "43.500 € – 78.500 €",
#         "posted_date": "Mathematiker/ Aktuar (m/w/d) Aktuarielle Bewertung Arbeitszeitmodell Standort Sofort Wir sind die DEVK.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Junior Mathematiker:in (Versicherung / Produktmathematik)",
#         "company_name": "Viridium Customer Services GmbH",
#         "location": "Hamburg",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Vor 4 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "(Junior) Mathematiker (m/w/d) Spieleentwicklung",
#         "company_name": "univativ GmbH",
#         "location": "Lübbecke",
#         "job_type": "42.000 € – 52.000 €",
#         "money": "42.000 € – 52.000 €",
#         "posted_date": "Dann suchen wir Dich als (Junior)Mathematikerin der Spieleentwicklung zum nächstmöglichen Zeitpunkt.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Versicherungs- / Wirtschafts-Mathematiker (m/w/d)",
#         "company_name": "Recruiter Netzwerk",
#         "location": "Stuttgart",
#         "job_type": "81.000 € – 92.000 €",
#         "money": "81.000 € – 92.000 €",
#         "posted_date": "Vor 5 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker:in Rückversicherung",
#         "company_name": "Sparkassen-Finanzgruppe",
#         "location": "Stuttgart",
#         "job_type": "56.500 € – 75.500 €",
#         "money": "56.500 € – 75.500 €",
#         "posted_date": "Vor 5 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Diplom-Informatiker/ Medizin- (Bio-)Informatiker / Mathematiker (Univ./FH)  (Elternzeitvert (m/w/d)",
#         "company_name": "Klinikum der Universität München",
#         "location": "München",
#         "job_type": "54.500 € – 82.000 €",
#         "money": "54.500 € – 82.000 €",
#         "posted_date": "Vor 8 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker/-in Pensionsversicherungsmathematik in der bAV (all genders)",
#         "company_name": "adesso benefit solutions GmbH",
#         "location": "Bensheim",
#         "job_type": "52.000 € – 72.500 €",
#         "money": "52.000 € – 72.500 €",
#         "posted_date": "Mathematiker/-inPensionsversicherungsmathematik in der bAV (all genders)Mathematiker/-inPensionsversicherungsmathematik in der bAV (all genders) Die adesso benefit",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker/ Physiker für die Revision in einer internationalen Bank (gn)",
#         "company_name": "PS Direkt GmbH & Co. KG Private Arbeitsvermittlung",
#         "location": "Köln",
#         "job_type": "54.500 € – 80.500 €",
#         "money": "54.500 € – 80.500 €",
#         "posted_date": "Für ein Kreditinstitut in Köln, suchen wir einenMathematiker/ Physiker für die Revision (gn) in Vollzeit.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker als Softwareentwickler (m/w/d) in der Krankenversicherung",
#         "company_name": "Continentale Versicherungsverbund",
#         "location": "Dortmund",
#         "job_type": "53.500 € – 75.000 €",
#         "money": "53.500 € – 75.000 €",
#         "posted_date": "Mathematikerals Softwareentwickler (m/w/d) in der Krankenversicherung",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker (m/w/d) im Versicherungswesen",
#         "company_name": "DIS AG",
#         "location": "Hamburg",
#         "job_type": "51.500 € – 68.000 €",
#         "money": "51.500 € – 68.000 €",
#         "posted_date": "Vor 17 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Wirtschaftsinformatiker/-in oder Mathematiker/-in im Rechnungswesen",
#         "company_name": "Commerzbank AG",
#         "location": "Halle (Saale)",
#         "job_type": "53.000 € – 76.000 €",
#         "money": "53.000 € – 76.000 €",
#         "posted_date": "Vor 17 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker (m/w/d) in der Lebensversicherung",
#         "company_name": "Continentale Versicherungsverbund",
#         "location": "München",
#         "job_type": "57.500 € – 76.500 €",
#         "money": "57.500 € – 76.500 €",
#         "posted_date": "Mathematiker(m/w/d) in der Lebensversicherung",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Junior Mathematiker:in (Direkteinstieg in die Interne Revision)",
#         "company_name": "Viridium Group Services GmbH",
#         "location": "Neu-Isenburg",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Vor 20 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker Softwareentwicklung (m/w/d)",
#         "company_name": "Brunel GmbH NL Karlsruhe",
#         "location": "Freiburg im Breisgau",
#         "job_type": "50.000 € – 70.500 €",
#         "money": "50.000 € – 70.500 €",
#         "posted_date": "Vor 22 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "(Wirtschafts-)Mathematiker/Physiker/Informatiker für Schnittstellenentwicklung im E-Commerce (m/w/d)",
#         "company_name": "RSU GmbH",
#         "location": "Ulm",
#         "job_type": "49.500 € – 55.500 €",
#         "money": "49.500 € – 55.500 €",
#         "posted_date": "Vor 23 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Physiker/Mathematiker für Messtechnikentwicklung (m/w/d)",
#         "company_name": "Brunel GmbH NL Ulm",
#         "location": "Ulm",
#         "job_type": "54.500 € – 74.000 €",
#         "money": "54.500 € – 74.000 €",
#         "posted_date": "Machen Sie noch heute den entscheidenden Schritt Ihrer Karriere und bewerben Sie sich bei uns als Physiker/Mathematikerfür Messtechnikentwicklung (m/w/d).",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker Softwareentwicklung (m/w/d)",
#         "company_name": "Brunel",
#         "location": "Freiburg im Breisgau",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Vor 25 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Physiker/Mathematiker für Messtechnikentwicklung (m/w/d)",
#         "company_name": "Brunel",
#         "location": "Ulm",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Machen Sie noch heute den entscheidenden Schritt Ihrer Karriere und bewerben Sie sich bei uns als Physiker/Mathematikerfür Messtechnikentwicklung (m/w/d).",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Physiker oder Mathematiker (m/w/d) als Systemingenieur",
#         "company_name": "FERCHAU GmbH",
#         "location": "Ulm",
#         "job_type": "65.000 € – 75.000 €",
#         "money": "65.000 € – 75.000 €",
#         "posted_date": "Physiker oderMathematiker(m/w/d) als Systemingenieur Das sind deine Aufgaben in unserem Team Analyse und Spezifikation der System-Requirements und -Schnittstellen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker:in / Aktuar:in (Quantitatives Risikomanagement / Versicherung)",
#         "company_name": "Viridium Group Services GmbH",
#         "location": "Leverkusen",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Vor 27 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Junior Mathematiker:in (Versicherung / Produktmathematik)",
#         "company_name": "Viridium Gruppe",
#         "location": "Neu-Isenburg",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Vor 27 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker:in / Aktuar:in (Quantitatives Risikomanagement / Versicherung)",
#         "company_name": "Viridium Group Services GmbH",
#         "location": "Neu-Isenburg",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Vor 28 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker (m/w/d) Pensionsfonds",
#         "company_name": "DEVK",
#         "location": "Köln",
#         "job_type": "46.500 € – 62.500 €",
#         "money": "46.500 € – 62.500 €",
#         "posted_date": "Mathematiker(m/w/d) Pensionsfonds Arbeitszeitmodell Vollzeit Standort 01.11.2024 Wir sind die DEVK.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker (m/w/d) Statistik und Datenanalyse in Mannheim (915)",
#         "company_name": "BRÜGGEN ENGINEERING GmbH",
#         "location": "Mannheim",
#         "job_type": "50.500 € – 70.500 €",
#         "money": "50.500 € – 70.500 €",
#         "posted_date": "Starten Sie Ihre Karriere alsMathematiker(m/w/d) Statistik und Datenanalyse bei BRÜGGEN ENGINEERING und werden Sie zur Schlüsselfigur in der pharmazeutischen Statistik",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker (m/w/d)",
#         "company_name": "Randstad Deutschland GmbH & Co. KG",
#         "location": "Mannheim",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "powered byMathematiker(m/w/d) Vertragsart Arbeitnehmerüberlassung Einsatzorte 68161 Mannheim Gehalt 90.000 - 109.000 EUR pro Jahr Beginn 01.11.2024 Arbeitszeitmodell",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker (m/w/d) Betriebliche Altersversorgung",
#         "company_name": "DEVK",
#         "location": "Köln",
#         "job_type": "46.500 € – 62.500 €",
#         "money": "46.500 € – 62.500 €",
#         "posted_date": "Mathematiker(m/w/d) Betriebliche Altersversorgung Arbeitszeitmodell Vollzeit Standort Sofort Wir sind die DEVK.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "(Business) Mathematician / Physicist Life and Health Reinsurance",
#         "company_name": "Hannover Rück SE",
#         "location": "Hannover",
#         "job_type": "58.000 € – 67.500 €",
#         "money": "58.000 € – 67.500 €",
#         "posted_date": "Vor 6 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker (m/w/d) für die fachliche Anwendungsentwicklung",
#         "company_name": "Generali Deutschland AG",
#         "location": "Aachen",
#         "job_type": "71.000 € – 84.500 €",
#         "money": "71.000 € – 84.500 €",
#         "posted_date": "Mathematiker(m/w/d) für die fachliche Anwendungsentwicklung in Aachen Überblick Die Generali ist eine der führenden Erstversicherungsgruppen im deutschen Markt.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker (m/w/d) für die Bestandsverwaltungssysteme der Lebensversicherung",
#         "company_name": "Generali Deutschland AG",
#         "location": "Aachen",
#         "job_type": "70.000 € – 81.500 €",
#         "money": "70.000 € – 81.500 €",
#         "posted_date": "Mathematiker(m/w/d) für die Bestandsverwaltungssysteme der Lebensversicherung in Aachen Überblick Die Generali ist eine der führenden Erstversicherungsgruppen im",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker im Aktuariat Finanzen (m/w/d)",
#         "company_name": "Allianz Deutschland",
#         "location": "München",
#         "job_type": "55.500 € – 80.000 €",
#         "money": "55.500 € – 80.000 €",
#         "posted_date": "Dann bieten wir Dir die Möglichkeit, das breite Aufgabenspektrum eines Aktuars (m/w/d) im Fachbereich Reservierung & Versicherungsmathematische Funktion alsMathematiker",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "IT-Affiner Physiker (m/w/d), Mathematiker (m/w/d) oder Ingenieur (m/w/d) für Bildverarbeitende Systeme",
#         "company_name": "Diehl Defence",
#         "location": "Röthenbach an der Pegnitz",
#         "job_type": "48.500 € – 80.500 €",
#         "money": "48.500 € – 80.500 €",
#         "posted_date": "IT-Affiner Physiker (m/w/d),Mathematiker(m/w/d) oder Ingenieur (m/w/d) für Bildverarbeitende Systeme Das sind Ihre Aufgaben: Sie arbeiten in einem interdisziplinären",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Informatiker/Mathematiker (m/w/d) - objektorientierte Softwareentwicklung in der Krankenversicherung",
#         "company_name": "Württembergische Versicherung AG",
#         "location": "Kornwestheim",
#         "job_type": "53.000 € – 82.000 €",
#         "money": "53.000 € – 82.000 €",
#         "posted_date": "Vor 30+ Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker Spielentwicklung ­­/­­ Game Design Mathematician (m|w|d)",
#         "company_name": "LÖWEN ENTERTAINMENT GmbH",
#         "location": "Mainz",
#         "job_type": "49.000 € – 55.500 €",
#         "money": "49.000 € – 55.500 €",
#         "posted_date": "MathematikerSpielentwicklung / Game Design Mathematician (m|w|d) Ihre Aufgaben Spielentwicklung: Sie entwickeln gemeinsam mit Game Designern Spielmechaniken und",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "(Wirtschafts-) Mathematiker m/w/d",
#         "company_name": "SÜDVERS Holding GmbH & Co. KG",
#         "location": "Idstein",
#         "job_type": "55.000 € – 73.500 €",
#         "money": "55.000 € – 73.500 €",
#         "posted_date": "(Wirtschafts-)Mathematikerm/w/d Arbeiten bei der PBG GmbH, einen Unternehmen der SÜDVERS Die PBG Pensions-Beratungs-Gesellschaft mbH in Idstein ist eine produkt",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker für den Berufseinstieg im Risikocontrolling (m/w/d)",
#         "company_name": "HOLISTIC42 GmbH",
#         "location": "Stuttgart",
#         "job_type": "48.500 € – 69.500 €",
#         "money": "48.500 € – 69.500 €",
#         "posted_date": "Aktuell suchen wir zur weiteren Verstärkung unseres Teams im Großraum Stuttgart ab sofortMathematikerfür den Berufseinstieg im Risikocontrolling (m/w/d) Darum",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker, Physiker, Informatiker, Modellentwickler (m/w/d) – Kreditrisiko",
#         "company_name": "S Rating und Risikosysteme GmbH",
#         "location": "Berlin",
#         "job_type": "50.000 € – 76.000 €",
#         "money": "50.000 € – 76.000 €",
#         "posted_date": "Mathematiker, Physiker, Informatiker, Modellentwickler (m/w/d) – Kreditrisiko ab sofort Die Sparkassen Rating und Risikosysteme (SR) ist der zentrale Dienstleister",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Senior Mathematician/Statistician (m/w/d)",
#         "company_name": "Hays Professional Solutions GmbH Standort Mannheim",
#         "location": "Mannheim",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Vor 30+ Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "(Business) Mathematician Underwriting French-Speaking Markets",
#         "company_name": "Hannover Rück SE",
#         "location": "Hannover",
#         "job_type": "55.500 € – 66.500 €",
#         "money": "55.500 € – 66.500 €",
#         "posted_date": "Vor 30+ Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "(Business-) Mathematician / Underwriter US Property",
#         "company_name": "Hannover Rück SE",
#         "location": "Hannover",
#         "job_type": "62.500 € – 84.000 €",
#         "money": "62.500 € – 84.000 €",
#         "posted_date": "Vor 30+ Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematician / Actuary Life and Health Model Development",
#         "company_name": "Hannover Rück SE",
#         "location": "Hannover",
#         "job_type": "57.500 € – 89.000 €",
#         "money": "57.500 € – 89.000 €",
#         "posted_date": "Vor 30+ Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "IT-Affiner Physiker (m/w/d), Mathematiker (m/w/d) oder Ingenieur (m/w/d), vorzugsweise mit Promotion",
#         "company_name": "Diehl Defence GmbH & Co. KG",
#         "location": "Überlingen",
#         "job_type": "50.000 € – 65.000 €",
#         "money": "50.000 € – 65.000 €",
#         "posted_date": "IT-Affiner Physiker (m/w/d),Mathematiker(m/w/d) oder Ingenieur (m/w/d), vorzugsweise mit Promotion Das sind Ihre Aufgaben: Sie arbeiten in einem interdisziplinären",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "IT-Affiner Physiker (m/w/d), Mathematiker (m/w/d) oder Ingenieur (m/w/d), vorzugsweise mit Promotion",
#         "company_name": "Diehl Defence",
#         "location": "Überlingen",
#         "job_type": "50.000 € – 82.500 €",
#         "money": "50.000 € – 82.500 €",
#         "posted_date": "IT-Affiner Physiker (m/w/d),Mathematiker(m/w/d) oder Ingenieur (m/w/d), vorzugsweise mit Promotion Das sind Ihre Aufgaben: Sie arbeiten in einem interdisziplinären",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker/Aktuar - Risikomanagement/Solvency II (d/m/w)",
#         "company_name": "aktuarielle Beratungsgesellschaft",
#         "location": "Köln",
#         "job_type": "48.500 € – 82.000 €",
#         "money": "48.500 € – 82.000 €",
#         "posted_date": "Bei MSK treffen Sie auf die höchsteMathematiker:innen-Dichte Kölns J. \"Wir freuen uns auf Sie!\"",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker und C#, .NET Developer (m/w/d)",
#         "company_name": "KA Resources",
#         "location": "Würzburg",
#         "job_type": "49.500 € – 67.000 €",
#         "money": "49.500 € – 67.000 €",
#         "posted_date": "Mathematikerund C#, .NET Developer (m/w/d) KA Resources 03.09.2024 Job Type Job Reference 28528 Workplace On-Site Estimated Salary bis zu 90.000 EUR / Jahr Industry",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker/Pricing-Aktuar (w/m/d) in Voll- oder Teilzeit",
#         "company_name": "VHV Allgemeine Versicherung AG",
#         "location": "Hannover",
#         "job_type": "69.000 € – 99.000 €",
#         "money": "69.000 € – 99.000 €",
#         "posted_date": "Mathematiker/Pricing-Aktuar (w/m/d) in Voll- oder Teilzeit Voll- oder Teilzeit, unbefristet Hybrid VHV-Platz 1, Hannover Mit Berufserfahrung 01.10.24 Zum nächstmöglichen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Actuary / Mathematician / Property Casualty",
#         "company_name": "Hannover Rück SE",
#         "location": "Hannover",
#         "job_type": "57.500 € – 82.500 €",
#         "money": "57.500 € – 82.500 €",
#         "posted_date": "Vor 30+ Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "EY-Parthenon Mathematiker - HR Transactions - Transaction Strategy & Execution (w/m/d)",
#         "company_name": "EY Deutschland",
#         "location": "Frankfurt am Main",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "EY-ParthenonMathematiker- HR Transactions - Transaction Strategy & Execution (w/m/d) Standort: Eschborn / Frankfurt (Main) Anderer Ort: Nur primärer Standort Gehalt",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker / Aktuar (m/w/d)",
#         "company_name": "Lebensversicherung von 1871 a. G. München",
#         "location": "München",
#         "job_type": "82.000 € – 107.500 €",
#         "money": "82.000 € – 107.500 €",
#         "posted_date": "Mathematiker/ Aktuar (m/w/d) Voll- oder Teilzeit Hybrid Maximilianspl. 5, 80333 München, Deutschland Mit Berufserfahrung 12.09.24 Das sind wir Wir, die Lebensversicherung",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker (m/w/d) Aktuariat Schaden- und Unfallversicherung (Teilzeit)",
#         "company_name": "Verband öffentlicher Versicherer",
#         "location": "Düsseldorf",
#         "job_type": "53.500 € – 76.500 €",
#         "money": "53.500 € – 76.500 €",
#         "posted_date": "Mathematiker(m/w/d) Aktuariat Schaden- und Unfallversicherung (Teilzeit) 13.06.2024 Kennziffer 1355 Gesellschaft Verband öffentlicher Versicherer (VöV) Ihre Aufgaben",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Informatiker/Ingenieur/ Physiker/ Mathematiker (m/w/d) für die Entwicklung von Embedded Software",
#         "company_name": "ITPower Solutions GmbH",
#         "location": "Berlin",
#         "job_type": "49.000 € – 65.500 €",
#         "money": "49.000 € – 65.500 €",
#         "posted_date": "Vor 30+ Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker:in für E-Learning-Plattform",
#         "company_name": "Mathelöser",
#         "location": "Köln",
#         "job_type": "Selbstständig",
#         "money": "Selbstständig",
#         "posted_date": "Vor 30+ Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker/Aktuar m/w/d",
#         "company_name": "VST Gesellschaft für Versicherungsstatistik mbH",
#         "location": "Hannover",
#         "job_type": "47.500 € – 78.500 €",
#         "money": "47.500 € – 78.500 €",
#         "posted_date": "Vor 30+ Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker - Aktuar - Versicherungsmathematiker (m/w/d) für die betriebliche Altersversorgung",
#         "company_name": "Lutz Pension Consulting GmbH",
#         "location": "Bergisch Gladbach",
#         "job_type": "51.500 € – 83.000 €",
#         "money": "51.500 € – 83.000 €",
#         "posted_date": "Zur Verstärkung unseres spezialisierten Teams suchen wir Sie als qualifizierten und motiviertenMathematiker/ Aktuar in Vollzeit - mit flexiblen Arbeitszeitmodellen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker:in Tarifierung (w/m/d)",
#         "company_name": "HUK-COBURG VVaG",
#         "location": "Coburg",
#         "job_type": "51.500 € – 69.000 €",
#         "money": "51.500 € – 69.000 €",
#         "posted_date": "Wir suchen Sie alsMathematiker:inTarifierung (w/m/d) Vollzeit, ab sofort oder 01.07.2024 in Coburg, befristet 31.12.2025 Berufserfahrene und Einsteiger:innen finden",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker:in / Physiker:in Aktuarielles Controlling (w/m/d)",
#         "company_name": "HUK-COBURG VVaG",
#         "location": "Coburg",
#         "job_type": "50.500 € – 66.000 €",
#         "money": "50.500 € – 66.000 €",
#         "posted_date": "Wir suchen Sie alsMathematiker:in/ Physiker:in Aktuarielles Controlling (w/m/d) Vollzeit, ab sofort in Coburg, unbefristet Berufserfahrene und Einsteiger:innen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Senior Aktuar/ Mathematiker Rückversicherung (m/w/d)",
#         "company_name": "DEVK",
#         "location": "Köln",
#         "job_type": "47.500 € – 77.500 €",
#         "money": "47.500 € – 77.500 €",
#         "posted_date": "Senior Aktuar/MathematikerRückversicherung (m/w/d) Arbeitszeitmodell Vollzeit Standort Sofort Wir sind die DEVK.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Consultant Karrierestart/Quereinstieg als WiWi, Mathematiker, Physiker - Financial Services (w/m/d)",
#         "company_name": "EY Deutschland",
#         "location": "Frankfurt am Main",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Consultant Karrierestart/Quereinstieg als WiWi,Mathematiker, Physiker - Financial Services (w/m/d) Standort: Eschborn / Frankfurt (Main) Anderer Ort: Bundesweit",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Praktikant Mathematiker, Informatiker, Physiker - prüfungsnahe Beratung/Quants (w/m/d)",
#         "company_name": "EY Deutschland",
#         "location": "Frankfurt am Main",
#         "job_type": "Für Studenten",
#         "money": "Für Studenten",
#         "posted_date": "PraktikantMathematiker, Informatiker, Physiker - prüfungsnahe Beratung/Quants (w/m/d) Standort: Eschborn / Frankfurt (Main) Anderer Ort: Nur primärer Standort Gehalt",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematician Underwriting",
#         "company_name": "Hannover Rück SE",
#         "location": "Hannover",
#         "job_type": "55.000 € – 66.500 €",
#         "money": "55.000 € – 66.500 €",
#         "posted_date": "Vor 30+ Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Economist / Mathematician / Underwriter Italy",
#         "company_name": "Hannover Rück SE",
#         "location": "Hannover",
#         "job_type": "58.500 € – 84.500 €",
#         "money": "58.500 € – 84.500 €",
#         "posted_date": "Vor 30+ Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker Softwareentwicklung (m/w/d)",
#         "company_name": "Guldberg GmbH",
#         "location": "Gilching",
#         "job_type": "50.000 € – 64.000 €",
#         "money": "50.000 € – 64.000 €",
#         "posted_date": "MathematikerSoftwareentwicklung (m/w/d) Ort: Gilching Ihre Aufgaben: Entwicklung von Algorithmen im Umfeld von 3D/ CAD / Roboter (Kinematiken) Programmierung in",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker (m/w/d) im quantitativen Risikomanagement",
#         "company_name": "Deutsche Bausparkasse Badenia AG",
#         "location": "Karlsruhe",
#         "job_type": "57.500 € – 84.000 €",
#         "money": "57.500 € – 84.000 €",
#         "posted_date": "Mathematiker(m/w/d) im quantitativen Risikomanagement in Karlsruhe Überblick Die Deutsche Bausparkasse Badenia, mit Sitz in Karlsruhe, zählt seit vielen Jahren",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker (w/m/d) Kompositversicherung",
#         "company_name": "Barmenia Versicherungen",
#         "location": "Wuppertal",
#         "job_type": "51.000 € – 64.500 €",
#         "money": "51.000 € – 64.500 €",
#         "posted_date": "Mathematiker(w/m/d) Kompositversicherung Deine Verantwortung Du kalkulierst Beiträge neuer (Nischen-)Produkte Du bist am Spartencontrolling beteiligt und erstellst",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker / Physiker als Softwareentwickler Quantitative Methoden (w|m|d)",
#         "company_name": "zeb.rolfes.schierenbeck.associates gmbh",
#         "location": "Berlin",
#         "job_type": "43.000 € – 63.500 €",
#         "money": "43.000 € – 63.500 €",
#         "posted_date": "Mathematiker/ Physiker als Softwareentwickler Quantitative Methoden (w|m|d) zeb Vollzeit , Unbefristet zum nächstmöglichen Zeitpunkt | Homeoffice möglich Berlin",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Physiker (m/w/d), Mathematiker (m/w/d) oder Ingenieur (m/w/d), vorzugsweise mit Promotion, für Algorithmen und Verfahren und deren Bewertung",
#         "company_name": "Diehl Defence",
#         "location": "Überlingen",
#         "job_type": "50.500 € – 79.500 €",
#         "money": "50.500 € – 79.500 €",
#         "posted_date": "Physiker (m/w/d),Mathematiker(m/w/d) oder Ingenieur (m/w/d), vorzugsweise mit Promotion, für Algorithmen und Verfahren und deren Bewertung Das sind Ihre Aufgaben",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Aktuar / Mathematiker (m/w/d) im Bereich Komposit-Versicherung",
#         "company_name": "Württembergische Versicherung AG",
#         "location": "Kornwestheim",
#         "job_type": "58.000 € – 89.000 €",
#         "money": "58.000 € – 89.000 €",
#         "posted_date": "Vor 30+ Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker / Physiker (m/w/d)",
#         "company_name": "R+V Versicherung",
#         "location": "Wiesbaden",
#         "job_type": "58.500 € – 83.000 €",
#         "money": "58.500 € – 83.000 €",
#         "posted_date": "Aufgaben FürMathematikerbietet R+V ein breites Spektrum an Einsatzgebieten.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker / Physiker / Chemiker als IT Berater (w/m/d)",
#         "company_name": "Best Practice Consulting AG",
#         "location": "Hamburg",
#         "job_type": "47.000 € – 64.000 €",
#         "money": "47.000 € – 64.000 €",
#         "posted_date": "Mathematiker/ Physiker / Chemiker als IT Berater (w/m/d) 18.09.2024 Aufgaben - Du wirkst von Beginn an bei SAP Projekten in allen Projektphasen mit – von der fachlichen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker (m/w/d) Tarifentwicklung Leben",
#         "company_name": "VOLKSWOHL BUND Versicherungen",
#         "location": "Dortmund",
#         "job_type": "54.500 € – 69.000 €",
#         "money": "54.500 € – 69.000 €",
#         "posted_date": "Mathematiker(m/w/d) Tarifentwicklung Leben Vollzeit Dortmund 18.09.24 miteinander. füreinander. erfolgreich.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker / Physiker / Chemiker als IT Berater (w/m/d)",
#         "company_name": "Best Practice Consulting AG",
#         "location": "Münster",
#         "job_type": "46.500 € – 64.000 €",
#         "money": "46.500 € – 64.000 €",
#         "posted_date": "Mathematiker/ Physiker / Chemiker als IT Berater (w/m/d) 18.09.2024 Aufgaben - Du wirkst von Beginn an bei SAP Projekten in allen Projektphasen mit – von der fachlichen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker / Naturwissenschaftler als Analyst (w/m/d)",
#         "company_name": "Allianz Deutschland",
#         "location": "Stuttgart",
#         "job_type": "53.000 € – 80.000 €",
#         "money": "53.000 € – 80.000 €",
#         "posted_date": "Das erwartet Dich bei uns alsMathematiker/ Naturwissenschaftler als Analyst (w/m/d) Du erarbeitest Verfahren für kalkulatorische Vertragsänderungen und entwirfst",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Junior Mathematiker:in (Versicherung / Solvency II)",
#         "company_name": "Viridium Holding AG",
#         "location": "Leverkusen",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Zum Ausbau des Bereichs Steuerung Lebensversicherung an unserem Standort Leverkusen suchen wir jetzt eine:n JuniorMathematiker:in(Versicherung / Solvency II) Worum",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "C++ Softwareentwickler ereignisorientierte Simulationen (m/w/d)",
#         "company_name": "DR. HARTMUTH & PARTNER",
#         "location": "München",
#         "job_type": "80.000 € – 120.000 €",
#         "money": "80.000 € – 120.000 €",
#         "posted_date": "Sie möchten Ihre Kenntnisse in der Modellbildung und Simulation vertiefen und Teil eines interdisziplinären Teams aus Softwareentwickler ,Mathematiker, Ingenieur",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Junior Aktuar / Junior Consultant (m/w/d)",
#         "company_name": "WTW",
#         "location": "Köln",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Verbinde bei uns die spannenden Aufgaben eines Unternehmensberaters mit deinen hervorragenden Fähigkeiten alsMathematiker*in: Arbeite mit unseren marktführenden",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Softwareentwickler (m/w/d) Triebswerks- und Komponentenerprobung",
#         "company_name": "PASIT Professionelle Personallösungen GmbH",
#         "location": "München",
#         "job_type": "48.000 € – 61.500 €",
#         "money": "48.000 € – 61.500 €",
#         "posted_date": "Hierfür eignen sich hervorragend Informatiker,Mathematikeroder Physiker.",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "C++ Softwareentwickler ereignisorientierte Simulationen (m/w/d)",
#         "company_name": "DR. HARTMUTH & PARTNER",
#         "location": "München",
#         "job_type": "80.000 € – 120.000 €",
#         "money": "80.000 € – 120.000 €",
#         "posted_date": "Sie möchten Ihre Kenntnisse in der Modellbildung und Simulation vertiefen und Teil eines interdisziplinären Teams aus Softwareentwickler ,Mathematiker, Ingenieur",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Java - Softwareentwickler verteilte Simulationen (m/w/d)",
#         "company_name": "DR. HARTMUTH & PARTNER",
#         "location": "München",
#         "job_type": "80.000 € – 120.000 €",
#         "money": "80.000 € – 120.000 €",
#         "posted_date": "In einem interdisziplinären Team aus Softwareentwickler ,Mathematiker, Ingenieur und Physiker entwickeln sie verteilte Simulationen, die zum Erfolg komplexer militärischer",
#         "Zu den ersten gehören": "Zu den Ersten gehören"
#     },
#     {
#         "job_title": "Softwareentwickler (m/w/d) Triebswerks- und Komponentenerprobung",
#         "company_name": "EMMA JOBS in München",
#         "location": "München",
#         "job_type": "49.000 € – 67.000 €",
#         "money": "49.000 € – 67.000 €",
#         "posted_date": "Hierfür eignen sich hervorragend Informatiker,Mathematikeroder Physiker.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Risikomanager (Mensch*) Schwerpunkt IKT",
#         "company_name": "Deutsche Rückversicherung AG",
#         "location": "Düsseldorf",
#         "job_type": "56.000 € – 90.500 €",
#         "money": "56.000 € – 90.500 €",
#         "posted_date": "Vor 4 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Dr. rer. nat. Physik / Chemie - Vorentwicklung & Projektmanagement (m/w/d)",
#         "company_name": "Professional Scientists GmbH & Co. KG",
#         "location": "Stuttgart",
#         "job_type": "51.500 € – 77.000 €",
#         "money": "51.500 € – 77.000 €",
#         "posted_date": "/ Theoretische Physik, Simulation, Optik Für unseren renommierten Kunden aus dem anwendungsnahen Forschungs- und Technologieumfeld, suchen wir einen Physiker /Mathematiker",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Entwicklungsingenieur Antennentechnik Flugzeug (w/m/d)",
#         "company_name": "AGILIOS Personal GmbH",
#         "location": "Manching",
#         "job_type": "54.500 € – 66.500 €",
#         "money": "54.500 € – 66.500 €",
#         "posted_date": ", Systeminformatiker (w/m/d), Ingenieur Elektrotechnik (w/m/d), Ingenieur Maschinenbau (w/m/d), Ingenieur Luft- und Raumfahrttechnik (w/m/d), Physiker (w/m/d),Mathematiker",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Referent (Mensch*) Spartenmanagement HUK",
#         "company_name": "Deutsche Rückversicherung AG",
#         "location": "Düsseldorf",
#         "job_type": "54.500 € – 83.000 €",
#         "money": "54.500 € – 83.000 €",
#         "posted_date": "Vor 5 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Consultant Market Research & Data Analytics (m/w/d)",
#         "company_name": "Instaffo GmbH",
#         "location": "Paderborn",
#         "job_type": "50.000 € – 70.000 €",
#         "money": "50.000 € – 70.000 €",
#         "posted_date": "Du findest Ökonom:innen, Psycholog:innen,Mathematiker:innen und Informatiker:innen – dieses vielseitige Umfeld garantiert den Blick über den Tellerrand und schafft",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Softwaretester (m/w/d)",
#         "company_name": "Brunel GmbH NL Erfurt",
#         "location": "Erfurt",
#         "job_type": "43.000 € – 61.000 €",
#         "money": "43.000 € – 61.000 €",
#         "posted_date": "Ihre Qualifikationen Informatiker,Mathematiker, Physiker, Ingenieur, Nachrichtentechniker oder ähnlich gut qualifiziert Idealerweise ISTQB-Zertifikat sowie erste",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Fachrevisor (m/w/d)",
#         "company_name": "Berlin Hyp AG",
#         "location": "Berlin",
#         "job_type": "61.000 € – 81.000 €",
#         "money": "61.000 € – 81.000 €",
#         "posted_date": "Auch Erfahrungen alsMathematiker*inoder Physiker*in in anderen Aufgaben sind für uns von Interesse.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Markt- und Institutsaufseher*innen (w/m/d) für die Wertpapieraufsicht / Asset-Management",
#         "company_name": "Bundesanstalt für Finanzdienstleistungsaufsicht (BaFin)",
#         "location": "Frankfurt am Main",
#         "job_type": "49.000 € – 72.000 €",
#         "money": "49.000 € – 72.000 €",
#         "posted_date": "Vor 10 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Softwaretester (m/w/d)",
#         "company_name": "Brunel",
#         "location": "Erfurt",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Ihr Profil Informatiker,Mathematiker, Physiker, Ingenieur, Nachrichtentechniker oder ähnlich gut qualifiziert Idealerweise ISTQB-Zertifikat sowie erste einschlägige",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Postdoc in Machine Learning & Non-invasive Tumor Profiling",
# ...
#         "location": "Mittweida",
#         "job_type": "Für Studenten",
#         "money": "Für Studenten",
#         "posted_date": "forschende Unternehmen der Hightech-Branche und IT-Industrie, die aufgrund der analytischen Fähigkeiten und der methodischen Kompetenzen bevorzugt Mathematikerinnen undMathematiker",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Lerntherapeut/in für Rechenschwäche am Standort Eberswalde gesucht",
#         "company_name": "Duden Institut für Lerntherapie Eberswalde",
#         "location": "Eberswalde",
#         "job_type": "46.500 € – 65.500 €",
#         "money": "46.500 € – 65.500 €",
#         "posted_date": "Psychologe/in, Sozialpädagoge/in, Lehrer/in oderMathematiker/in) mit Bereitschaft, eine berufsbegleitende Zusatzqualifikation zu erwerben hohe Eigenverantwortung",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Promotionsstelle in der Physikalischen Ozeanographie und Messtechnik",
#         "company_name": "Leibniz-Institut für Ostseeforschung Warnemünde",
#         "location": "Rostock",
#         "job_type": "47.000 € – 51.500 €",
#         "money": "47.000 € – 51.500 €",
#         "posted_date": "geförderten Sonderforschungsbereichs TRR181 \"Energy Transfers in Atmosphere and Ocean\", in dem physikalische Ozeanographinnen, Atmosphärenwissenschaftlerinnen undMathematiker",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Dr. rer. nat. Physik / Chemie – Vorentwicklung & Projektmanagement (m/w/d)",
#         "company_name": "Professional Scientists GmbH & Co. KG",
#         "location": "Stuttgart",
#         "job_type": "53.000 € – 83.000 €",
#         "money": "53.000 € – 83.000 €",
#         "posted_date": "/ Theoretische Physik, Simulation, Optik Für unseren renommierten Kunden aus dem anwendungsnahen Forschungs- und Technologieumfeld, suchen wir einen Physiker /Mathematiker",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Masterarbeit / Abschlussarbeit mit Fokus auf Operations Research (all genders)",
#         "company_name": "INFORM Institut für Operations Research und Management GmbH",
#         "location": "Aachen",
#         "job_type": "Für Studenten",
#         "money": "Für Studenten",
#         "posted_date": "Ergebnisse auf Basis dessen du in einen Dialog mit dem Team und deinem Betreuer gehst Was du dafür mitbringst: Abgeschlossenes Bachelorstudium als Informatiker*in oderMathematiker*in",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "IT Support Mitarbeiter - Kundenbetreuung (all genders)",
#         "company_name": "INFORM Institut für Operations Research und Management GmbH",
#         "location": "Aachen",
#         "job_type": "35.500 € – 55.500 €",
#         "money": "35.500 € – 55.500 €",
#         "posted_date": "Was du dafür mitbringst: Abgeschlossene Ausbildung als Fachinformatiker*in für Systemintegration oder ein abgeschlossenes Studium als Wirtschaftsinformatiker*in,Mathematiker*in",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Senior Fullstack Developer (all genders) – im KI Bereich",
#         "company_name": "INFORM Institut für Operations Research und Management GmbH",
#         "location": "Aachen",
#         "job_type": "49.500 € – 76.500 €",
#         "money": "49.500 € – 76.500 €",
#         "posted_date": "B. als Informatiker*in, Softwareentwickler*in oderMathematiker*inist wünschenswert Wie wir deine Arbeit wertschätzen: Flexible Arbeitszeiten, Remote Work, Workation",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "IT Projektmanager (all genders) - Workforce Management",
#         "company_name": "INFORM Institut für Operations Research und Management GmbH",
#         "location": "Aachen",
#         "job_type": "45.500 € – 72.500 €",
#         "money": "45.500 € – 72.500 €",
#         "posted_date": "mit deinem Erfahrungsschatz im Projektgeschäft zur Seite Was du dafür mitbringst: Abgeschlossenes Studium als Wirtschaftsinformatiker*in, Informatiker*in, MATSE,Mathematiker*in",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Embedded System Engineer (w/m/d)",
#         "company_name": "Brunel GmbH NL Hannover",
#         "location": "Hannover",
#         "job_type": "49.500 € – 72.500 €",
#         "money": "49.500 € – 72.500 €",
#         "posted_date": "Ihre Qualifikationen Informatiker,Mathematiker, Wirtschaftsinformatiker oder ähnlich gut qualifiziert - sei es durch ein Studium, durch Berufspraxis oder als Autodidakt",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Embedded System Engineer (w/m/d)",
#         "company_name": "Brunel",
#         "location": "Hannover",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Ihr Profil Informatiker,Mathematiker, Wirtschaftsinformatiker oder ähnlich gut qualifiziert - sei es durch ein Studium, durch Berufspraxis oder als Autodidakt.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Trainee im Bereich IT (m/w/d)",
#         "company_name": "Holistic42 GmbH",
#         "location": "Ludwigsburg",
#         "job_type": "Für Studenten",
#         "money": "Für Studenten",
#         "posted_date": "Mitarbeiterangeboten Unsere Empfehlungsprogramm \"Mitarbeiter-werben-Mitarbeiter\" So sieht dein Weg vom Junior zum Experten aus: Egal ob Entwickler, Consultant,Mathematiker",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Ingenieur (m/w/d) Physikalische Berechnungen",
#         "company_name": "FERCHAU GmbH",
#         "location": "Essen",
#         "job_type": "55.000 € – 70.000 €",
#         "money": "55.000 € – 70.000 €",
#         "posted_date": "Vor 26 Tagen",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "(Wirtschafts-)Mathematiker/Statistiker (m/w/d)",
#         "company_name": "hkp/// group",
#         "location": "Frankfurt am Main",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Lass uns gemeinsam wachsen und die Arbeitswelt von morgen gestalten (Wirtschafts-)Mathematiker/Statistiker (m/w/d) Die hkp/// group ist das führende Beratungshaus",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Data Science - Studentische Hilfskraft / Praktikant/-in (m/w/d)",
#         "company_name": "logarithmo GmbH & Co. KG",
#         "location": "Dortmund",
#         "job_type": "Für Studenten",
#         "money": "Für Studenten",
#         "posted_date": "In unseren interdisziplinären Teams ergänzen sich Softwareentwickler,Mathematiker, Ingenieure und Designer.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Data Science Consultant (m/w/d)",
#         "company_name": "Sopra Steria Consulting",
#         "location": "Deutschland",
#         "job_type": "57.500 € – 83.000 €",
#         "money": "57.500 € – 83.000 €",
#         "posted_date": "Psycholog*innen, Betriebswirt*innen,Mathematiker*innen und Informatiker*innen.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "(Senior-) Software Developer Prognose & KI",
#         "company_name": "Robotron Schweiz GmbH",
#         "location": "Dresden",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "oder Spezifikationen (Bewertung, Lösungsvorschläge, Strukturierung in Einzelleistungen und Aufwandsschätzung) Anforderungen Studium – oder Berufsabschluss alsMathematiker",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Datascientist*in oder Mathematiker*in (m/w/d) [German speaker only]",
#         "company_name": "Cavorit Consulting GmbH",
#         "location": "Forst (Lausitz)",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Derzeit suchen wir eine/n Datascientist*in oderMathematiker*indie/der unser Team bei der Entwicklung von Datenprodukten unterstützt.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Fachbereich Mathematik und Informatik - Institut für Mathematik AG Diskrete Geometrie & Topologische Kombinatorik",
#         "company_name": "Freie Universität Berlin",
#         "location": "Berlin",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Die Einstellung erfolgt unter Vorbehalt der Bewilligung der Drittmittel durch die DeutscheMathematiker-Vereinigung.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Java Entwickler (w/m/d)",
#         "company_name": "Axians Athos GmbH",
#         "location": "Sindelfingen",
#         "job_type": "48.000 € – 75.500 €",
#         "money": "48.000 € – 75.500 €",
#         "posted_date": "Du bist Informatiker, Ingenieur,Mathematiker, Naturwissenschaftler oder hast eine Ausbildung zum Fachinformatiker?",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Mathematiker (m/w/d) im Risk Management mit Schwerpunkt Risikosysteme",
#         "company_name": "Swiss Life Holding",
#         "location": "Garching bei München",
#         "job_type": "56.500 € – 65.500 €",
#         "money": "56.500 € – 65.500 €",
#         "posted_date": "Mathematiker(m/w/d) im Risk Management mit Schwerpunkt Risikosysteme Garching b.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Junior Consultant Data Science Telecommunication & Media (m/w/d)",
#         "company_name": "Sopra Steria Consulting",
#         "location": "Deutschland",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "der Erstellung von eigenen Prototypen und findest innovative Lösungen Unsere interdisziplinären Teams umfassen unter anderem Psycholog*Innen, Betriebswirt*innen,Mathematiker",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Java - Softwareentwickler verteilte Simulationen (m/w/d)",
#         "company_name": "IABG",
#         "location": "Ottobrunn bei München",
#         "job_type": "51.500 € – 73.500 €",
#         "money": "51.500 € – 73.500 €",
#         "posted_date": "Sie möchten Systemverantwortung innerhalb eines interdisziplinären Team von erfahrenen Softwareentwickler:innen,Mathematiker:innen, Ingenieur:innen und Physiker",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "C++ Softwareentwickler ereignisorientierte Simulationen (m/w/d)",
#         "company_name": "IABG",
#         "location": "Ottobrunn bei München",
#         "job_type": "53.500 € – 77.000 €",
#         "money": "53.500 € – 77.000 €",
#         "posted_date": "Sie möchten Systemverantwortung innerhalb eines interdisziplinären Teams von erfahrenen Softwareentwickler:innen,Mathematiker:innen, Ingenieur:innen und Physiker",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Data Scientist Datenmanagement",
#         "company_name": "aktuarielle Beratungsgesellschaft",
#         "location": "Köln",
#         "job_type": "48.500 € – 74.500 €",
#         "money": "48.500 € – 74.500 €",
#         "posted_date": "Gestalten Sie mit einem hochqualifizierten Team vonMathematiker:innen die digitale Zukunft der Versicherungswirtschaft!",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Aktuarieller Consultant Lebensversicherung (w/m/d)",
#         "company_name": "HBA-Consulting AG",
#         "location": "Idstein",
#         "job_type": "52.500 € – 77.500 €",
#         "money": "52.500 € – 77.500 €",
#         "posted_date": "HBA-Consultants sind oftmals weltoffene IT-affineMathematikerund sehen die Optimierung der IT-Unterstützung als ihr Ziel.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Senior Fullstack Java/Angular Developer (M/E/N/S/C/H)",
#         "company_name": "WhizUs GmbH",
#         "location": "Wien",
#         "job_type": "60.000 € – 85.000 €",
#         "money": "60.000 € – 85.000 €",
#         "posted_date": "Vom technischenMathematiker, über den Software Entwickler bis hin zum System Administrator versuchen wir gemeinsam interessante Projekte umzusetzen und so die IT-Welt",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Cloud Native Engineer (M/E/N/S/C/H)",
#         "company_name": "WhizUs GmbH",
#         "location": "Wien",
#         "job_type": "60.000 € – 90.000 €",
#         "money": "60.000 € – 90.000 €",
#         "posted_date": "Vom technischenMathematiker, über den Software Entwickler bis hin zum System Administrator versuchen wir gemeinsam interessante Projekte umzusetzen und so die IT-Welt",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Business Analyst Personenversicherung Rechenkern (m/w/d)",
#         "company_name": "R+V Versicherung",
#         "location": "Wiesbaden",
#         "job_type": "58.000 € – 91.000 €",
#         "money": "58.000 € – 91.000 €",
#         "posted_date": "Profil / Anforderungen Du bist ein erfahrener Aktuar,Mathematikeroder verfügst über hinreichende mathematische Vorbildung.",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Werkstudent (Wirtschafts-) Mathematik / Physik / Informatik (m/w/d)",
#         "company_name": "R+V Versicherung",
#         "location": "Wiesbaden",
#         "job_type": "Für Studenten",
#         "money": "Für Studenten",
#         "posted_date": "IT-affinerMathematiker? Zu wenig Programmierung?",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Testmanager (w/m/d)",
#         "company_name": "Barmenia Versicherungen",
#         "location": "Wuppertal",
#         "job_type": "52.500 € – 77.000 €",
#         "money": "52.500 € – 77.000 €",
#         "posted_date": "Projektverantwortlichen und der Fachbereiche beim Aufbau und der Durchführung von Last- und Performancetests Deine Kompetenz Betriebswirt, (Wirtschafts-)Informatiker,Mathematiker",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Machine Learning Entwickler:in",
#         "company_name": "alfatraining Bildungszentrum GmbH",
#         "location": "Hannover",
#         "job_type": "Selbstständig",
#         "money": "Selbstständig",
#         "posted_date": "Ihr Einsatzbereich Sie unterrichten Informatiker:innen,Mathematiker:innen, Elektrotechniker:innen sowie Personen mit Studium der (Wirtschafts-) Ingenieurwissenschaften",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Machine Learning Entwickler:in",
#         "company_name": "alfatraining Bildungszentrum GmbH",
#         "location": "Rostock",
#         "job_type": "Selbstständig",
#         "money": "Selbstständig",
#         "posted_date": "Ihr Einsatzbereich Sie unterrichten Informatiker:innen,Mathematiker:innen, Elektrotechniker:innen sowie Personen mit Studium der (Wirtschafts-) Ingenieurwissenschaften",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Projektleiter:in im SAP-Umfeld",
#         "company_name": "GAB-Solution GmbH",
#         "location": "Berlin",
#         "job_type": "61.000 € – 99.500 €",
#         "money": "61.000 € – 99.500 €",
#         "posted_date": "Projekterfolg Qualifikation Ein abgeschlossenes Hochschulstudium als (Wirtschafts-)Informatiker/in, Wirtschaftsingenieur/in, Betriebs- oder Volkswirt/in, Physiker/in,Mathematiker/in",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Revisor (m/w/d) mit Schwerpunkt IT",
#         "company_name": "Cobalt Deutschland GmbH",
#         "location": "Berlin",
#         "job_type": "46.000 € – 74.500 €",
#         "money": "46.000 € – 74.500 €",
#         "posted_date": "Das Anforderungsprofil Erfolgreich abgeschlossenes (Fach-)Hochschulstudium der Wirtschafts- oder Fachinformatik oder vergleichbare IT-Qualifikation oder Diplom-Mathematiker",
#         "Zu den ersten gehören": " "
#     },
#     {
#         "job_title": "Software Entwickler*In (w/m/d)",
#         "company_name": "Stiefsohn Consulting GmbH",
#         "location": "Österreich",
#         "job_type": "Vollzeit",
#         "money": "Vollzeit",
#         "posted_date": "Wir besteh en aus einer bunten Mischung aus Tech niker*Innen,Mathematiker*Innen, Informatiker*In nen und Betriebswirt*Innen .",
#         "Zu den ersten gehören": " "
#     }
# ]

# %%
import sqlite3
from bs4 import BeautifulSoup
import json

# Funktion zur Extraktion und Speicherung der Jobdetails in eine SQLite-Datenbank
def extract_and_store_job_details_in_db(html: str, db_path: str):
    # Parse the HTML
    soup = BeautifulSoup(html, 'html.parser')

    # Find all relevant job cards
    job_cards = soup.find_all('li', class_='css-5lfssm')

    if not job_cards:
        print("No job cards found")
        return

    # Verbindung zur SQLite-Datenbank herstellen (wird erstellt, falls sie nicht existiert)
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    # Tabelle erstellen, falls sie noch nicht existiert
    cursor.execute('''CREATE TABLE IF NOT EXISTS jobs (
                        id INTEGER PRIMARY KEY AUTOINCREMENT,
                        job_title TEXT,
                        company_name TEXT,
                        location TEXT,
                        rating TEXT,
                        job_type TEXT,
                        posted_date TEXT,
                        job_description TEXT
                    )''')

    for job_card in job_cards:
        try:
            # Extract job details
            job_title = job_card.find('span', {'id': lambda x: x and x.startswith('jobTitle')}).get_text(strip=True)
            company_name = job_card.find('span', {'data-testid': 'company-name'}).get_text(strip=True)
            location = job_card.find('div', {'data-testid': 'text-location'}).get_text(strip=True)
            rating = job_card.find('span', {'data-testid': 'holistic-rating'}).get_text(strip=True)
            job_type = job_card.find('div', {'data-testid': 'attribute_snippet_testid'}).get_text(strip=True)
            posted_date = job_card.find('span', {'data-testid': 'myJobsStateDate'}).get_text(strip=True)

            # Extract job description points
            job_description_items = job_card.find_all('li')
            job_description = "\n".join([item.get_text(strip=True) for item in job_description_items])

            # Jobdetails in die Datenbank einfügen
            cursor.execute('''INSERT INTO jobs (job_title, company_name, location, rating, job_type, posted_date, job_description)
                              VALUES (?, ?, ?, ?, ?, ?, ?)''', 
                           (job_title, company_name, location, rating, job_type, posted_date, job_description))
        
        except AttributeError:
            print("Failed to parse job card")

    # Änderungen speichern und Verbindung schließen
    conn.commit()
    conn.close()

# Beispielaufruf der Funktion
db_path = 'jobs.db'  # Pfad zur SQLite-Datenbank
extract_and_store_job_details_in_db(html, db_path)

# %% [markdown]
# Mehr laden. anzahl suchen und so lange laden bis anzahl erreicht ist
# for der daten baank nach duplication suchen

# %%
github einlesen

# %%
postgresql
